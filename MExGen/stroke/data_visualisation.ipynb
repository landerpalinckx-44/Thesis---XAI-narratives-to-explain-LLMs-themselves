# %% [markdown]
# # 1. Imports

# %%
import pickle
import glob
import re
import os
import json
import textwrap
import math
from types import SimpleNamespace
from collections import defaultdict
from itertools import cycle

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns

from mexgen_story import MExGenStory
import config

# %%
# --- Load attribution data from pkl files ---
pkl_files = sorted(glob.glob("mexgen_results/mexgen_results_instance_*.pkl"))

dfs = {}

for fname in pkl_files:
    with open(fname, "rb") as f:
        mexgen_results = pickle.load(f)

    data       = mexgen_results["output_dict_words"]
    units      = data["attributions"]["units"]
    scores     = data["attributions"]["bert"]
    unit_types = data["attributions"]["unit_types"]

    attribution_df = pd.DataFrame([
        {"token": unit.strip(), "attribution_score": round(float(score), 4)}
        for unit, score, utype in zip(units, scores, unit_types)
        if utype == "w"
    ]).assign(position=lambda df: range(len(df))) \
      .sort_values("attribution_score", ascending=False) \
      .reset_index(drop=True)

    instance_id = int(re.search(r"instance_(\d+)", fname).group(1))
    dfs[instance_id] = attribution_df

# --- Load log (narratives + evaluations) ---
with open(config.LOG_JSON, "r") as f:
    log = json.load(f)

# Convenience lookup: {instance_id (int): log entry}
log_by_instance = {e["instance_index"]: e for e in log}

# Filter to evaluated entries only
log_evaluated = [e for e in log if "evaluations" in e]

instances = sorted(set(e["instance_index"] for e in log_evaluated))
personas  = sorted(set(
    p for e in log_evaluated
    for p in e["evaluations"].keys()
))

ASPECTS = config.JUDGE_ASPECTS
MODELS  = config.JUDGE_MODELS

# %% [markdown]
# # 2. Print all attribution scores

# %%
for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    print(df[["token", "attribution_score"]].to_string(index=False))
# Out:
# === instance_0 ===
#             token  attribution_score
#            gender             1.0000
#               age             0.6154
#              67.0             0.2967
#              Male             0.2793
#               Yes             0.2296
#    smoking_status             0.2123
#      ever_married             0.2087
#      hypertension             0.2075
#                 1             0.2013
#     heart_disease             0.1979
#               bmi             0.1886
#             Urban             0.1760
#              36.6             0.1726
#          formerly             0.1570
#    Residence_type             0.1508
#            smoked             0.1486
# avg_glucose_level             0.1305
#            228.69             0.0932
#         work_type             0.0881
#           Private             0.0710
#                 0            -0.0036
#
# === instance_4 ===
#             token  attribution_score
#              79.0             1.0000
#                 1             0.8595
#    smoking_status             0.0055
#     heart_disease             0.0045
#               bmi             0.0031
#          employed             0.0017
#              24.0            -0.0003
#      hypertension            -0.0034
#            smoked            -0.0264
#             never            -0.0282
#            Female            -0.0295
#              Self            -0.0311
#      ever_married            -0.0311
#                 0            -0.0312
#            174.12            -0.0313
#               age            -0.0325
# avg_glucose_level            -0.0361
#               Yes            -0.0366
#             Rural            -0.0368
#            gender            -0.0369
#    Residence_type            -0.0384
#         work_type            -0.0385
#
# === instance_17 ===
#             token  attribution_score
#               age             0.5673
#            gender             0.2296
#      hypertension             0.2091
#                 1             0.1706
#               bmi             0.1084
#     heart_disease             0.1075
#      ever_married             0.0741
#             Urban             0.0555
#            smokes             0.0000
#               Yes            -0.0576
#              25.8            -0.0857
#            221.29            -0.0892
#    smoking_status            -0.1796
#    Residence_type            -0.2501
#           Private            -0.2814
#                 0            -0.2826
#         work_type            -0.2917
# avg_glucose_level            -0.3310
#              75.0            -0.9399
#              Male            -1.0000
#
# === instance_30 ===
#             token  attribution_score
#              57.0             0.2840
#      ever_married             0.1168
#     heart_disease             0.1138
#              Male             0.0619
#    smoking_status            -0.1068
#            212.08            -0.1242
#             Urban            -0.1599
#            smokes            -0.1599
#         work_type            -0.1663
#               Yes            -0.1739
#    Residence_type            -0.1860
#              44.2            -0.2651
# avg_glucose_level            -0.3159
#               bmi            -0.4180
#      hypertension            -0.4641
#                 1            -0.4895
#           Private            -0.5326
#                 0            -0.7006
#            gender            -0.9514
#               age            -1.0000
#
# === instance_49 ===
#             token  attribution_score
#               bmi             1.0000
#              39.2             0.9649
#                 1             0.5943
#            smokes             0.4536
#    Residence_type             0.2875
#      hypertension             0.2673
#             Rural             0.1436
#            gender             0.1348
#     heart_disease             0.1090
#           Private             0.1008
#      ever_married             0.0963
#               Yes            -0.0362
#             58.09            -0.0697
#         work_type            -0.0697
#               age            -0.0697
# avg_glucose_level            -0.0708
#              39.0            -0.0724
#                 0            -0.0775
#            Female            -0.0777
#    smoking_status            -0.0777
#
# === instance_825 ===
#             token  attribution_score
#            smokes             1.0000
#              59.0             0.7989
#         work_type             0.6046
#    Residence_type             0.4883
#            gender             0.4356
#              27.3             0.3543
#             Rural             0.2223
#              Male             0.1819
#               Yes             0.1757
#          Govt_job             0.1336
#    smoking_status             0.0895
#      ever_married             0.0864
#               age            -0.0417
#             73.75            -0.0476
#      hypertension            -0.0495
#                 0            -0.0517
# avg_glucose_level            -0.0922
#               bmi            -0.0997
#     heart_disease            -0.1369
#                 0            -0.1369
#
# === instance_924 ===
#             token  attribution_score
#                 0             1.0000
#                 0             0.1721
#              74.0             0.1432
#             never             0.1237
#    smoking_status             0.0711
#           Private             0.0691
# avg_glucose_level             0.0689
#             87.11             0.0589
#            Female             0.0515
#               Yes             0.0222
#               bmi             0.0204
#             Urban             0.0197
#         work_type             0.0186
#            smoked             0.0163
#    Residence_type             0.0145
#      ever_married             0.0143
#            gender             0.0142
#              24.8             0.0142
#               age             0.0141
#      hypertension            -0.0015
#     heart_disease            -0.0380
#
# === instance_1295 ===
#             token  attribution_score
#                 0             1.0000
#             never             0.8977
#                 0             0.8069
#               age             0.6323
#               bmi             0.6108
#      hypertension             0.5156
#         work_type             0.3131
#              60.0             0.1393
#               Yes             0.1053
#     heart_disease             0.0594
#             Rural             0.0558
#              Male             0.0274
#      ever_married             0.0217
#            gender             0.0073
#           Private            -0.0110
# avg_glucose_level            -0.0527
#            101.34            -0.1016
#    Residence_type            -0.1053
#    smoking_status            -0.1145
#              32.8            -0.1487
#            smoked            -0.1565
#
# === instance_1322 ===
#             token  attribution_score
#               bmi             1.0000
#             206.4             0.9640
#              54.8             0.0061
#                 1             0.0013
#            gender            -0.0010
#            Female            -0.0277
#             never            -0.0297
#             Urban            -0.0309
#    Residence_type            -0.0309
#     heart_disease            -0.0310
#         work_type            -0.0310
#           Private            -0.0316
#                 0            -0.0330
#            smoked            -0.0331
#      hypertension            -0.0342
# avg_glucose_level            -0.0343
#               Yes            -0.0346
#    smoking_status            -0.0364
#               age            -0.0364
#      ever_married            -0.0380
#              55.0            -0.0381
#
# === instance_1362 ===
#             token  attribution_score
#                 0             1.0000
#            Female             0.8426
#                 0             0.8260
#          formerly             0.6321
#               bmi             0.5959
#      hypertension             0.3486
#     heart_disease             0.2994
#            gender             0.0921
#               age             0.0908
#              26.9             0.0904
#            103.25             0.0695
#    smoking_status             0.0572
#          employed             0.0462
#              Self             0.0434
# avg_glucose_level             0.0291
#             Rural             0.0262
#               Yes             0.0260
#    Residence_type             0.0076
#      ever_married             0.0042
#              72.0            -0.0174
#         work_type            -0.0656
#            smoked            -0.1446

# %% [markdown]
# for reference: {attribution_table} which gets added to the narrative prompt (mexgen_story.py) and faithfulness evaluation prompt (evaluation_prompts.py)

# %%
storyteller = MExGenStory(api_key="dummy", model_name="dummy")

pkl_path = "mexgen_results/mexgen_results_instance_0.pkl"
with open(pkl_path, "rb") as f:
    mexgen_results = pickle.load(f)

attribution_df = storyteller.build_attribution_df(
    mexgen_results["output_dict_words"],
    mexgen_results["scalarizer"],
)
print(attribution_df.to_string(index=False))
# Out:
#             token  attribution_score
#            gender           1.000000
#               age           0.615379
#              67.0           0.296693
#              Male           0.279288
#               Yes           0.229567
#    smoking_status           0.212290
#      ever_married           0.208663
#      hypertension           0.207472
#                 1           0.201328
#     heart_disease           0.197867
#               bmi           0.188587
#             Urban           0.175990
#              36.6           0.172648
#         formerly            0.157049
#    Residence_type           0.150812
#            smoked           0.148624
# avg_glucose_level           0.130469
#            228.69           0.093157
#         work_type           0.088068
#           Private           0.071011
#                 0          -0.003605

# %% [markdown]
# ## 2b. Print all evaluations

# %%
for entry in log_evaluated:
    instance_id = entry["instance_index"]
    print(f"\n=== instance_{instance_id} ===")
    rows = []
    for persona, aspects in entry["evaluations"].items():
        for aspect, data in aspects.items():
            agg = data.get("aggregate_score")
            rows.append({"persona": persona, "aspect": aspect, "aggregate_score": agg})
    df_agg = pd.DataFrame(rows)
    print(df_agg.to_string(index=False))
# Out:
# === instance_0 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness             3.25
#      expert_judge  helpfulness             5.00
#      expert_judge plausibility             3.50
#           patient faithfulness             5.00
#           patient  helpfulness             5.00
#           patient plausibility             2.00
#            doctor faithfulness             5.00
#            doctor  helpfulness             3.50
#            doctor plausibility             2.00
# patient_elaborate faithfulness             4.50
# patient_elaborate  helpfulness             3.50
# patient_elaborate plausibility             2.00
#  doctor_elaborate faithfulness             3.00
#  doctor_elaborate  helpfulness             2.00
#  doctor_elaborate plausibility             2.00
#
# === instance_1295 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              4.0
#           patient faithfulness              4.0
#           patient  helpfulness              4.0
#           patient plausibility              4.0
#            doctor faithfulness              4.0
#            doctor  helpfulness              4.5
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.0
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              3.0
#  doctor_elaborate faithfulness              2.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              3.0
#
# === instance_1322 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              3.0
#           patient faithfulness              4.5
#           patient  helpfulness              5.0
#           patient plausibility              3.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.0
#            doctor plausibility              3.5
# patient_elaborate faithfulness              5.0
# patient_elaborate  helpfulness              3.0
# patient_elaborate plausibility              2.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              2.0
#
# === instance_1362 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              5.0
#           patient faithfulness              4.0
#           patient  helpfulness              5.0
#           patient plausibility              4.0
#            doctor faithfulness              4.0
#            doctor  helpfulness              5.0
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              3.0
#  doctor_elaborate faithfulness              4.0
#  doctor_elaborate  helpfulness              3.5
#  doctor_elaborate plausibility              2.0
#
# === instance_17 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness            2.000
#      expert_judge  helpfulness            3.500
#      expert_judge plausibility            2.500
#           patient faithfulness            2.625
#           patient  helpfulness            3.500
#           patient plausibility            2.000
#            doctor faithfulness            2.000
#            doctor  helpfulness            3.500
#            doctor plausibility            3.000
# patient_elaborate faithfulness            2.750
# patient_elaborate  helpfulness            3.000
# patient_elaborate plausibility            2.000
#  doctor_elaborate faithfulness            1.500
#  doctor_elaborate  helpfulness            2.000
#  doctor_elaborate plausibility            2.000
#
# === instance_30 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              1.0
#      expert_judge  helpfulness              1.5
#      expert_judge plausibility              1.0
#           patient faithfulness              1.0
#           patient  helpfulness              1.5
#           patient plausibility              1.5
#            doctor faithfulness              1.0
#            doctor  helpfulness              1.5
#            doctor plausibility              1.5
# patient_elaborate faithfulness              1.0
# patient_elaborate  helpfulness              1.0
# patient_elaborate plausibility              1.0
#  doctor_elaborate faithfulness              1.0
#  doctor_elaborate  helpfulness              1.0
#  doctor_elaborate plausibility              1.0
#
# === instance_4 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              5.0
#           patient faithfulness              5.0
#           patient  helpfulness              5.0
#           patient plausibility              5.0
#            doctor faithfulness              5.0
#            doctor  helpfulness              5.0
#            doctor plausibility              5.0
# patient_elaborate faithfulness              5.0
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.5
#  doctor_elaborate faithfulness              5.0
#  doctor_elaborate  helpfulness              4.5
#  doctor_elaborate plausibility              4.5
#
# === instance_49 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              4.0
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.0
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.0
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              3.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              4.0
#
# === instance_825 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.0
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              4.0
#
# === instance_924 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              1.0
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              4.5
#           patient faithfulness              1.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              2.0
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              2.0
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.5
#  doctor_elaborate faithfulness              1.0
#  doctor_elaborate  helpfulness              5.0
#  doctor_elaborate plausibility              4.0

# %% [markdown]
# # 3. Print everything for specific instance

# %%
instance_id = 4

entry = log_by_instance[instance_id]
df = dfs[instance_id]

print(f"=== Instance {instance_id} ===")
print(f"\nLLM response: '{entry['baseline_response']}'")

print(f"\nAttributions (sorted by influence):")
print(df[["token", "attribution_score"]].to_string(index=False))

print(f"\nNarrative:")
print(textwrap.fill(entry["story"], width=150))

print(f"\nEvaluation scores (final score per judge):")
for persona, aspects in entry.get("evaluations", {}).items():
    print(f"\n  {'='*50}")
    print(f"  {persona.replace('_', ' ').title()}")
    print(f"  {'='*50}")
    for aspect, models in aspects.items():
        agg = models.get("aggregate_score")
        print(f"    {aspect.capitalize():<15} aggregate: {agg}")
        for model in config.JUDGE_MODELS:
            data = models.get(model, {})
            score = data.get("final_score") if isinstance(data, dict) else None
            short_model = model.split("/")[-1]
            print(f"      {short_model:<35} {score}")
# Out:
# === Instance 4 ===
#
# LLM response: 'High'
#
# Attributions (sorted by influence):
#             token  attribution_score
#              79.0             1.0000
#                 1             0.8595
#    smoking_status             0.0055
#     heart_disease             0.0045
#               bmi             0.0031
#          employed             0.0017
#              24.0            -0.0003
#      hypertension            -0.0034
#            smoked            -0.0264
#             never            -0.0282
#            Female            -0.0295
#              Self            -0.0311
#      ever_married            -0.0311
#                 0            -0.0312
#            174.12            -0.0313
#               age            -0.0325
# avg_glucose_level            -0.0361
#               Yes            -0.0366
#             Rural            -0.0368
#            gender            -0.0369
#    Residence_type            -0.0384
#         work_type            -0.0385
#
# Narrative:
# When the AI model looked at this patient profile to decide if the stroke risk was "High" or "Low," it didn't weigh every detail equally; instead, it
# acted like a focused detective zeroing in on two specific clues. The most dominant factor by far was the number **79.0**, which carried the maximum
# possible influence score, suggesting the model views advanced age as the primary gateway to a high-risk category. Right behind it was the number **1**
# next to hypertension, a digital "red flag" that signaled a significant medical warning to the AI. Interestingly, almost every other detail—like the
# patient living in a rural area, being married, or her specific glucose level—actually had a slight negative influence, meaning these facts tried to
# pull the model toward a "Low" risk answer. However, the sheer weight of being 79 with high blood pressure was so overwhelming that these smaller
# details were effectively drowned out. The AI’s logic was simplified: regardless of a healthy BMI or a history of never smoking, the combination of age
# and hypertension made a "High" risk verdict inevitable. This reveals that the model operates on a hierarchy where certain medical "deal-breakers" can
# override a dozen other positive lifestyle factors. Even though the patient had many "Low" risk traits, the model's internal math decided that age and
# hypertension were the only signals that truly mattered.  **Summary:** The AI reached its "High" risk conclusion by focusing almost exclusively on the
# patient's age (79) and hypertension status, which outweighed all other personal and lifestyle factors combined.
#
# Evaluation scores (final score per judge):
#
#   ==================================================
#   Expert Judge
#   ==================================================
#     Faithfulness    aggregate: 4
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           1
#     Helpfulness     aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Plausibility    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#
#   ==================================================
#   Patient
#   ==================================================
#     Faithfulness    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Helpfulness     aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Plausibility    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#
#   ==================================================
#   Doctor
#   ==================================================
#     Faithfulness    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Helpfulness     aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Plausibility    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#
#   ==================================================
#   Patient Elaborate
#   ==================================================
#     Faithfulness    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   5
#       grok-4.20                           5
#     Helpfulness     aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#
#   ==================================================
#   Doctor Elaborate
#   ==================================================
#     Faithfulness    aggregate: 5
#       gpt-5.4                             3.5
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Helpfulness     aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5

# %% [markdown]
# # 4. Print narratives

# %%
for entry in log:
    print(f"=== Instance: {entry['instance_index']} ===")
    print(f"LLM response: '{entry['baseline_response']}'")
    print(f"Narrative:\n{textwrap.fill(entry['story'], width=150)}")
    print()
# Out:
# === Instance: 0 ===
# LLM response: 'High'
# Narrative:
# Think of the AI as a digital medical assistant that scans a patient’s file, looking for specific "red flags" that match its training on stroke
# patterns. When it reviewed this patient and predicted a **"High"** risk, it wasn't looking at every detail equally; instead, it fixated heavily on
# identity and demographic markers. The word **"gender"** was the single most powerful trigger, suggesting the model relies heavily on the broad
# statistical differences between men and women as its primary starting point. It then combined this with the patient's **"age"** of **67.0** and the
# fact that he is **"Male,"** creating a foundation of high-risk demographic factors that outweighed specific medical numbers.  While lifestyle factors
# like being **"formerly smoked"** and having **"heart disease"** did add to the concern, they were secondary to these core identity markers.
# Interestingly, the patient's lack of hypertension (represented by the **"0"**) actually pulled the model slightly in the opposite direction, but its
# influence was too weak to change the final verdict. The AI essentially built a narrative where being an older male was the most significant predictor,
# with high glucose and BMI serving as supporting evidence rather than the main drivers.  **Summary:** The model predicted a high risk primarily because
# it prioritized the patient's category—an older male—over specific clinical measurements like blood sugar or blood pressure. This highlights how LLMs
# often rely on broad demographic "shortcuts" to reach a conclusion.
#
# === Instance: 1295 ===
# LLM response: 'Low'
# Narrative:
# When the AI looked at this patient’s profile, it acted like a digital detective searching for specific clues to justify a "Low" risk rating. Its
# strongest "green lights" were the zeros next to hypertension and heart disease, indicating that the absence of these chronic conditions was the
# foundation of its decision. The word "never" in the smoking status also stood out as a powerful anchor, signaling to the model that the patient’s
# lungs and arteries lacked a major source of stress. Interestingly, while the specific number "60.0" had only a mild impact, the word "age" itself was
# highly influential, suggesting the model prioritized the *concept* of the patient's age as a framework for risk. Conversely, the model had to look
# past some conflicting data, such as a higher "bmi" and the word "smoked," which momentarily pulled it toward a higher risk assessment. Ultimately, the
# absence of disease and the "never smoked" status were so mathematically heavy that they outweighed those minor red flags. This shows that the AI
# doesn't just read a list; it weighs certain "safety" words more heavily than others to reach a conclusion.  **Summary:** The AI predicted a low risk
# primarily because the zeros for hypertension and heart disease, combined with the word "never" regarding smoking, acted as the strongest influencers.
# These positive health markers successfully outweighed the negative pressure from the patient's BMI and age.
#
# === Instance: 1322 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a focused investigator who prioritize specific "red flags" above all else. Although the
# patient had several health factors, the model’s prediction of "High" risk was almost entirely dominated by two specific markers: the label for body
# mass index (**bmi**) and the high blood sugar reading (**206.4**). These two data points stood out with massive influence, while other
# information—like the patient’s age of 55 or her status as a non-smoker—actually had a slight "negative" influence, meaning they would typically
# suggest a lower risk. Interestingly, the actual BMI number (**54.8**) and the presence of hypertension carried surprisingly little weight compared to
# the mere mention of the word "bmi" itself and the glucose value. This suggests the model has "learned" to trigger a high-risk warning the moment it
# sees evidence of obesity and high blood sugar, even if other factors like being a non-smoker try to pull the prediction in the opposite direction.
# Essentially, the model functioned like a filter that tuned out the background noise of the patient's lifestyle to focus intensely on her metabolic
# indicators.  **Summary:** The AI reached its "High" risk conclusion by fixating on the **bmi** category and the high **206.4** glucose level, which
# outweighed all other factors. Surprisingly, standard risk drivers like age and hypertension were treated as almost irrelevant compared to these two
# dominant signals.
#
# === Instance: 1362 ===
# LLM response: 'Low'
# Narrative:
# To understand how the AI reached a "Low" risk prediction for this 72-year-old patient, imagine the model as a detective looking for specific "green
# lights" that signal safety. Even though the patient is older, the AI was most heavily influenced by the presence of the number **0** next to
# hypertension and heart disease, treating these as powerful indicators of health. The word **"Female"** also acted as a strong anchor for its decision,
# suggesting the model relied heavily on demographic and clinical "zeros" to justify its low-risk conclusion. Interestingly, while the patient
# **"formerly"** smoked, the model prioritized that word as a positive sign of current behavioral change rather than a lingering threat. Meanwhile,
# technical markers like the **"bmi"** score of 26.9 were viewed as stable, middle-of-the-road values that didn't alarm the system. Most surprising is
# what the model ignored; the patient’s **age (72.0)** and **glucose level** had almost no impact on the final answer, appearing nearly invisible to the
# AI’s logic. By focusing on the absence of disease (those "zeros") rather than the risks of aging, the model felt "confident" enough to produce its
# "Low" risk response.  **Summary:** The model arrived at a "Low" risk prediction by prioritizing the absence of heart disease and hypertension (the "0"
# values) and the patient's gender over significant risk factors like her advanced age, which it largely ignored.
#
# === Instance: 17 ===
# LLM response: 'High'
# Narrative:
# Imagine the AI as a medical examiner who focuses on specific "red flags" while surprisingly ignoring others. When determining that this patient was at
# "High" risk, the AI was most heavily swayed by the general categories of **Age**, **Gender**, and **Hypertension**, treating these labels as the
# primary foundation for its decision. Interestingly, the specific numerical data—like the actual age of **75.0** or the blood sugar level of
# **221.29**—actually had negative scores, meaning these specific numbers paradoxically confused the model or pushed it toward a "Low" risk answer. The
# model essentially relied on the "headers" of the patient's profile to make a snap judgment, viewing the mere presence of the "Hypertension" category
# and the patient’s status as a "Male" as more definitive than the actual severity of the health stats provided. Even though the patient smokes and
# lives in an urban area, these factors were almost entirely ignored compared to the heavy weight placed on biological basics. This suggests the AI is
# acting like a pattern-matcher that prioritizes broad risk categories over the fine-grained details of a person's actual health numbers. Ultimately,
# the model's "High" prediction was driven by the high-level concepts of aging and blood pressure rather than the specific, alarming data points like
# high glucose.  **Summary:** The AI reached its "High" risk conclusion by prioritizing general risk labels like age and hypertension while ignoring or
# being confused by the specific numerical measurements.
#
# === Instance: 30 ===
# LLM response: 'High'
# Narrative:
# When the AI predicted a "High" stroke risk for this patient, it didn't just look at a medical checklist; it engaged in a complex weighing process
# where some data points acted as anchors while others created significant "noise." Interestingly, the patient’s age of 57 and the presence of heart
# disease were the strongest positive drivers, signaling to the model that these were primary indicators of risk. However, the most fascinating part of
# the AI's "thought process" is found in the negative scores, where labels like "gender," "age," and "hypertension" actually pulled the model away from
# its final answer. This suggests that the AI might have been confused by the way the data was labeled or felt that the specific values—like the high
# BMI of 44.2 or the glucose level—didn't fit its internal pattern for a "typical" high-risk case. Despite these conflicting signals from the labels and
# certain lifestyle factors like working in the "Private" sector, the raw facts of the patient’s age and heart health eventually tipped the scale. The
# model essentially had to fight through its own uncertainty regarding the patient's "Urban" lifestyle and "smokes" status to reach its conclusion. In
# the end, the sheer weight of being a 57-year-old male with heart disease concerns overcame the "distractions" provided by the other health metrics.
# **Summary:** The AI reached a "High" risk conclusion because it prioritized age and heart disease history as the most reliable signals, even though it
# found the specific formatting of the health labels and supporting factors like BMI and glucose levels to be statistically inconsistent or "confusing"
# during its processing.
#
# === Instance: 4 ===
# LLM response: 'High'
# Narrative:
# When the AI model looked at this patient profile to decide if the stroke risk was "High" or "Low," it didn't weigh every detail equally; instead, it
# acted like a focused detective zeroing in on two specific clues. The most dominant factor by far was the number **79.0**, which carried the maximum
# possible influence score, suggesting the model views advanced age as the primary gateway to a high-risk category. Right behind it was the number **1**
# next to hypertension, a digital "red flag" that signaled a significant medical warning to the AI. Interestingly, almost every other detail—like the
# patient living in a rural area, being married, or her specific glucose level—actually had a slight negative influence, meaning these facts tried to
# pull the model toward a "Low" risk answer. However, the sheer weight of being 79 with high blood pressure was so overwhelming that these smaller
# details were effectively drowned out. The AI’s logic was simplified: regardless of a healthy BMI or a history of never smoking, the combination of age
# and hypertension made a "High" risk verdict inevitable. This reveals that the model operates on a hierarchy where certain medical "deal-breakers" can
# override a dozen other positive lifestyle factors. Even though the patient had many "Low" risk traits, the model's internal math decided that age and
# hypertension were the only signals that truly mattered.  **Summary:** The AI reached its "High" risk conclusion by focusing almost exclusively on the
# patient's age (79) and hypertension status, which outweighed all other personal and lifestyle factors combined.
#
# === Instance: 49 ===
# LLM response: 'High'
# Narrative:
# When the AI looked at this patient profile, it acted less like a holistic doctor and more like a focused inspector, zeroing in on a few specific red
# flags to reach its "High" risk prediction. The most powerful driver was the patient’s BMI of 39.2; these two data points held the highest influence,
# essentially acting as the heavy weights that tipped the scale toward a high-risk category. Interestingly, while the patient’s history of hypertension
# and current smoking status added significant momentum to this decision, other traditional factors like her relatively young age of 39 were almost
# entirely ignored. Even though age is usually a major factor in stroke risk, the model’s internal logic prioritized physical health
# markers—specifically obesity and high blood pressure—over the fact that she is still young. Factors like her glucose level and gender actually pushed
# slightly in the opposite direction, but their influence was so weak compared to the "BMI" signal that they couldn't change the outcome. This tells us
# the AI viewed the combination of a high BMI and hypertension as a critical "danger zone" that outweighed everything else. In essence, the model made
# its decision by prioritizing physical lifestyle indicators and medical conditions over demographic details like age or employment.  **Summary:** The
# AI predicted a high risk primarily because it was heavily influenced by the patient's high BMI and hypertension, while largely disregarding her
# younger age as a protective factor.
#
# === Instance: 825 ===
# LLM response: 'High'
# Narrative:
# When the AI reviewed the patient’s profile, it acted like a digital detective looking for specific "red flags" that outweighed everything else. The
# word **"smokes"** was the most powerful clue in the entire file, acting as the primary reason the model flagged the patient as **High** risk. Close
# behind was the age of **59.0**, which provided the critical context that the patient's lifestyle choices were occurring in a higher-risk age bracket.
# Interestingly, the model was also heavily swayed by the labels **"work_type"** and **"Residence_type,"** suggesting it relies on these social
# categories to categorize health risks more than we might expect. Meanwhile, medical data that humans usually prioritize—like the patient’s **glucose
# level** or the fact that they had **no history of heart disease**—actually pushed the model *away* from a high-risk conclusion. Because those healthy
# medical markers had negative attribution scores, they were effectively ignored in favor of the smoking status and age. Ultimately, the model’s "High"
# prediction was a result of the habits and age of the patient drowning out the more positive clinical numbers. This shows us that the AI doesn't just
# look at health; it prioritizes certain lifestyle labels above medical history.  **Summary:** The AI predicted a high stroke risk primarily because of
# the patient’s smoking status and age, allowing these factors to overshadow healthy clinical readings like blood sugar and the absence of heart
# disease.
#
# === Instance: 924 ===
# LLM response: 'Low'
# Narrative:
# When the AI evaluated this patient’s medical profile, it acted like a digital detective looking for specific "clues" to determine her stroke risk. The
# most powerful clues leading it to choose **"Low"** were the zeros identifying that she had no history of hypertension or heart disease, which the
# model prioritized above all else. Even though her age of 74 is typically a major risk factor, the AI was more impressed by the word "never" in her
# smoking status and her healthy glucose levels. Interestingly, her age and BMI actually had very little impact on the final decision compared to those
# critical "0" markers for heart health. The model essentially weighed the absence of chronic illness more heavily than the natural risks of getting
# older. It also found small reassurance in her "Private" work sector and "Urban" residence, though these were minor details in its logic. By
# mathematically "muting" different words, the C-LIME analysis proved the AI was specifically hunting for those protective zeros. In short, the model
# saw a patient who, despite her age, lacked the specific medical triggers that usually lead to a high-risk rating.  **Summary:** The AI predicted a
# "Low" risk because it prioritized the absence of heart disease and hypertension (the "0" values) and her "never smoked" status over her age, viewing
# these as the strongest indicators of health.

# %% [markdown]
# # 5. Visualisations

# %% [markdown]
# ## 5.1 Attribution score plot of prompt

# %% [markdown]
# custom visualisation function

# %%
def print_colored_text(df, max_width=150):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["attribution_score"].abs().max()

    def get_color(value):
        # 2. Map the value so that 0 is exactly 0.5 (neutral)
        if max_abs == 0:
            norm_value = 0.5
        else:
            norm_value = (value + max_abs) / (2 * max_abs)
            
        if norm_value < 0.5:
            r = int(255 * (norm_value * 2))
            g = int(255 * (norm_value * 2))
            b = 255
        else:
            r = 255
            g = int(255 * (2 - norm_value * 2))
            b = int(255 * (2 - norm_value * 2))
        return r, g, b

    current_width = 0
    for _, row in df.iterrows():
        token = row["token"]
        token_width = len(token) + 1  # +1 for the space
        if current_width + token_width > max_width:
            print()
            current_width = 0
        r, g, b = get_color(row["attribution_score"])
        print(f"\033[38;2;{r};{g};{b}m{token}\033[0m", end=' ')
        current_width += token_width
    print()

def plot_colored_text(df, title="", max_width=0.95, fontsize=11, save_path=None):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["attribution_score"].abs().max()

    # Build lines by measuring real rendered text widths
    fig, ax = plt.subplots(figsize=(14, 2))
    renderer = fig.canvas.get_renderer()

    lines = []
    current_line = []
    current_width = 0.0

    for _, row in df.iterrows():
        # Measure the actual rendered width of this token
        t = ax.text(0, 0, row["token"] + " ", fontsize=fontsize, transform=ax.transAxes)
        bbox = t.get_window_extent(renderer=renderer)
        t.remove()
        token_width = bbox.width / fig.get_window_extent(renderer=renderer).width

        if current_line and current_width + token_width > max_width:
            lines.append(current_line)
            current_line = []
            current_width = 0.0
        current_line.append((row, token_width))
        current_width += token_width

    if current_line:
        lines.append(current_line)

    plt.close(fig)

    # Now draw the real figure
    num_lines = len(lines)
    fig, ax = plt.subplots(figsize=(14, num_lines * 0.5 + 1.5))
    ax.axis('off')

    y_step = 0.85 / (num_lines)
    y_pos = 0.95

    for line in lines:
        x_pos = 0.02
        for row, token_width in line:
            # 2. Map the value for the coolwarm colormap
            if max_abs == 0:
                norm_value = 0.5
            else:
                norm_value = (row["attribution_score"] + max_abs) / (2 * max_abs)
                
            color = plt.cm.coolwarm(norm_value)
            ax.text(x_pos, y_pos, row["token"], color=color, fontsize=fontsize,
                    ha='left', va='top', transform=ax.transAxes)
            x_pos += token_width
        y_pos -= y_step

    if title:
        ax.set_title(title, fontsize=13, pad=10)

    # 3. Update the colorbar to be strictly symmetrical (-max_abs to max_abs)
    sm = plt.cm.ScalarMappable(
        cmap=plt.cm.coolwarm, 
        norm=plt.Normalize(vmin=-max_abs, vmax=max_abs)
    )
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.05)
    cbar.set_label('C-LIME Attribution Score', fontsize=11)

    plt.tight_layout()
    
    # Save the figure if a path is provided
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        
    plt.show()

# %%
# 1. Update the folder path to include the 'attributions' subfolder
save_dir = os.path.join('visualisations', 'attributions')
os.makedirs(save_dir, exist_ok=True)

for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    df_ordered = df.sort_values("position")  # original sentence order

    # Print to terminal
    print_colored_text(df_ordered)
    
    # 2. Point the save_file to the new directory
    save_file = os.path.join(save_dir, f"attributions_{instance_id}.svg")

    # Plot and save
    plot_colored_text(df_ordered, title=f"instance_{instance_id}", save_path=save_file)
# Out:
# === instance_0 ===
# gender Male age 67.0 hypertension 0 heart_disease 1 ever_married Yes work_type Private Residence_type Urban avg_glucose_level 228.69 bmi 36.6
# smoking_status formerly smoked
# === instance_4 ===
# gender Female age 79.0 hypertension 1 heart_disease 0 ever_married Yes work_type Self employed Residence_type Rural avg_glucose_level 174.12 bmi 24.0
# smoking_status never smoked
# === instance_17 ===
# gender Male age 75.0 hypertension 1 heart_disease 0 ever_married Yes work_type Private Residence_type Urban avg_glucose_level 221.29 bmi 25.8
# smoking_status smokes
# === instance_30 ===
# gender Male age 57.0 hypertension 1 heart_disease 0 ever_married Yes work_type Private Residence_type Urban avg_glucose_level 212.08 bmi 44.2
# smoking_status smokes
# === instance_49 ===
# gender Female age 39.0 hypertension 1 heart_disease 0 ever_married Yes work_type Private Residence_type Rural avg_glucose_level 58.09 bmi 39.2
# smoking_status smokes
# === instance_825 ===
# gender Male age 59.0 hypertension 0 heart_disease 0 ever_married Yes work_type Govt_job Residence_type Rural avg_glucose_level 73.75 bmi 27.3
# smoking_status smokes
# === instance_924 ===
# gender Female age 74.0 hypertension 0 heart_disease 0 ever_married Yes work_type Private Residence_type Urban avg_glucose_level 87.11 bmi 24.8
# smoking_status never smoked
# === instance_1295 ===
# gender Male age 60.0 hypertension 0 heart_disease 0 ever_married Yes work_type Private Residence_type Rural avg_glucose_level 101.34 bmi 32.8
# smoking_status never smoked
# === instance_1322 ===
# gender Female age 55.0 hypertension 1 heart_disease 0 ever_married Yes work_type Private Residence_type Urban avg_glucose_level 206.4 bmi 54.8
# smoking_status never smoked
# === instance_1362 ===
# gender Female age 72.0 hypertension 0 heart_disease 0 ever_married Yes work_type Self employed Residence_type Rural avg_glucose_level 103.25 bmi 26.9
# smoking_status formerly smoked

# %% [markdown]
# ## 5.2 Narrative evaluation

# %%
os.makedirs("visualisations/evaluation", exist_ok=True)

# %% [markdown]
# ### Plot 1: Evaluation heatmaps

# %%
# ---------------------------------------------------------------------------
# Helper — extract scores from a single entry
# Returns: {aspect: {model: score}}
# ---------------------------------------------------------------------------
def extract_scores(entry: dict, persona: str) -> dict:
    scores = {}
    for aspect in ASPECTS:
        scores[aspect] = {}
        aspect_data = entry["evaluations"][persona].get(aspect, {})
        for model in MODELS:
            model_data = aspect_data.get(model, {})
            scores[aspect][model] = model_data.get("final_score", None)
    return scores

# %%
# ---------------------------------------------------------------------------
# PLOT 1 — Per-instance heatmaps
# Rows: judge models + aggregate row, Cols: aspects
# One image per persona, one heatmap per instance
# ---------------------------------------------------------------------------
short_models = [m.split("/")[-1] for m in MODELS]
row_labels   = short_models + ["Aggregate"]
n_instances  = len(instances)

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated
                       if persona in e.get("evaluations", {})}

    fig1, axes1 = plt.subplots(n_instances, 1, figsize=(6, 2.2 * n_instances))
    if n_instances == 1:
        axes1 = [axes1]

    for ax_idx, instance in enumerate(instances):
        ax    = axes1[ax_idx]
        entry = persona_entries.get(instance)

        if entry is None:
            ax.set_visible(False)
            continue

        scores = extract_scores(entry, persona)

        # Individual judge rows — same as before
        judge_matrix = np.array([
            [scores[aspect].get(model, np.nan) for aspect in ASPECTS]
            for model in MODELS
        ], dtype=float)

        # Aggregate row
        agg_row = np.array([
            entry["evaluations"][persona].get(aspect, {}).get("aggregate_score", np.nan)
            for aspect in ASPECTS
        ], dtype=float).reshape(1, -1)

        matrix = np.vstack([judge_matrix, agg_row])

        # Draw dividing line between judges and aggregate
        # by using a masked annotation style: bold for aggregate row
        sns.heatmap(
            matrix,
            ax=ax,
            annot=True,
            fmt=".1f",
            vmin=1, vmax=5,
            cmap="RdYlGn",
            xticklabels=[a.capitalize() for a in ASPECTS],
            yticklabels=row_labels,
            linewidths=0.5,
            linecolor="white",
            cbar=False,
        )

        # Bold the aggregate row label and draw a separator line
        yticklabels = ax.get_yticklabels()
        yticklabels[-1].set_fontweight("bold")
        ax.set_yticklabels(yticklabels)

        # Horizontal separator above aggregate row
        ax.axhline(y=len(MODELS), color="black", linewidth=1.5)

        ax.set_title(f"Instance {instance}", fontsize=11,
                     fontweight="bold", pad=8)
        ax.set_ylabel("")
        ax.set_xlabel("Aspect")

    fig1.suptitle(
        f"Per-Instance Evaluation Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig1.tight_layout()
    fig1.subplots_adjust(top=1)

    filename = f"visualisations/evaluation/evaluation_heatmaps_{persona}.svg"
    fig1.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig1)
# Out:
# Saved visualisations/evaluation/evaluation_heatmaps_doctor.svg
# Saved visualisations/evaluation/evaluation_heatmaps_doctor_elaborate.svg
# Saved visualisations/evaluation/evaluation_heatmaps_expert_judge.svg
# Saved visualisations/evaluation/evaluation_heatmaps_patient.svg
# Saved visualisations/evaluation/evaluation_heatmaps_patient_elaborate.svg

# %% [markdown]
# ####    Plot 1b: Aggregate heatmap

# %%
# ---------------------------------------------------------------------------
# PLOT 1b — Heatmap: instances (rows) x aspects (cols)
# Value: aggregate_score averaged across personas
# Good for spotting outlier instances at a glance
# ---------------------------------------------------------------------------

# Build: instance -> aspect -> mean aggregate score across personas
instance_aspect_means = {}
for instance in instances:
    instance_aspect_means[instance] = {}
    for aspect in ASPECTS:
        scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in log_evaluated
            if e["instance_index"] == instance
            for persona in personas
            if persona in e.get("evaluations", {})
            and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        instance_aspect_means[instance][aspect] = np.mean(scores) if scores else np.nan
        
matrix = np.array([
    [instance_aspect_means[inst][aspect] for aspect in ASPECTS]
    for inst in instances
])

fig, ax = plt.subplots(figsize=(5, max(6, len(instances) * 0.4)))
sns.heatmap(
    matrix,
    ax=ax,
    annot=True,
    fmt=".1f",
    vmin=1, vmax=5,
    cmap="RdYlGn",
    xticklabels=[a.capitalize() for a in ASPECTS],
    yticklabels=[f"#{inst}" for inst in instances],
    linewidths=0.4,
    cbar_kws={"label": "Aggregate score"},
)
ax.set_title("Aggregate Score Heatmap", fontweight="bold")
ax.set_xlabel("Aspect")
ax.set_ylabel("Instance")

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_heatmap.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_heatmap.svg")
plt.close(fig)
# Out:
# Saved aggregate_heatmap.svg

# %% [markdown]
# ### Plot 2: Average scores (over all instances) per Judge and Persona

# %%
rows = []
for e in log_evaluated:
    instance = e["instance_index"]
    for persona, aspects in e["evaluations"].items():
        for aspect, models_data in aspects.items():
            for model in MODELS:
                data = models_data.get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                rows.append({
                    "instance": instance,
                    "persona": persona.replace("_", " ").title(),
                    "aspect": aspect.capitalize(),
                    "model": model.split("/")[-1],
                    "score": score,
                })

df_long = pd.DataFrame(rows).dropna(subset=["score"])

# %% [markdown]
# strip plot

# %%
fig, axes = plt.subplots(1, len(ASPECTS), figsize=(5 * len(ASPECTS), 5), sharey=True)

for i, (ax, aspect) in enumerate(zip(axes, ASPECTS)):
    data = df_long[df_long["aspect"] == aspect.capitalize()]
    sns.stripplot(
        data=data, x="persona", y="score", hue="model",
        dodge=True, jitter=0.15, ax=ax, alpha=0.5, size=6,
    )
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("Score (1-5)" if i == 0 else "")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.tick_params(axis="x", rotation=20)

    if aspect.lower() != "plausibility":
        ax.legend_.remove()
    else:
        ax.legend(title="Judge", fontsize=7, title_fontsize=8, loc="lower right")

fig.suptitle("Score Distribution per Persona & Judge", fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/strip_all_judges.svg", dpi=150, bbox_inches="tight")
plt.close(fig)

# %% [markdown]
# bar chart

# %%
cmap_models = matplotlib.colormaps.get_cmap("tab10")
colors_personas = [cmap_models(i / len(personas)) for i in range(len(personas))]

n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
bar_fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

for model in MODELS:
    short_model = model.split("/")[-1]

    fig_bar, ax_bar = plt.subplots(figsize=(bar_fig_width, 5))

    persona_aspect_means = {}
    for persona in personas:
        persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
        means = {}
        for aspect in ASPECTS:
            scores = [
                e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score")
                for e in persona_entries
                if isinstance(e["evaluations"][persona].get(aspect, {}).get(model, {}), dict)
                and e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score") is not None
            ]
            means[aspect] = np.mean(scores) if scores else 0
        persona_aspect_means[persona] = means

    x = np.arange(len(ASPECTS))

    for i, (persona, means) in enumerate(persona_aspect_means.items()):
        values = [means[a] for a in ASPECTS]
        offset = (i - n_personas / 2 + 0.5) * width
        bars = ax_bar.bar(
            x + offset, values, width,
            label=persona.replace("_", " ").title(),
            color=colors_personas[i], alpha=0.85
        )
        for bar, val in zip(bars, values):
            ax_bar.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.2f}", ha="center", va="bottom", fontsize=9
            )

    ax_bar.set_xticks(x)
    ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
    ax_bar.set_ylim(0.5, 5.5)
    ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
    ax_bar.set_ylabel("Average score over all instances")
    ax_bar.set_title(f"Average Scores per Aspect & Persona — {short_model}", fontweight="bold")
    ax_bar.legend()
    ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

    fig_bar.tight_layout()
    filename_bar = f"visualisations/evaluation/evaluation_summary_bar_{short_model}.svg"
    fig_bar.savefig(filename_bar, dpi=150, bbox_inches="tight")
    print(f"Saved {filename_bar}")
    plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_summary_bar_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_summary_bar_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_summary_bar_grok-4.20.svg

# %% [markdown]
# #### Plot 2b: Average scores (over all instances) of aggregated scores per Persona

# %% [markdown]
# The aggregate score is the majority-voted score across all judge models for a given aspect and instance — so if 3 out of 5 models give a score of 2, the aggregate score is 2. The averaged aggregate score in the bar chart then takes these per-instance aggregate scores and averages them across all 20 instances to give a single summary score per aspect per persona.

# %%
n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

cmap   = matplotlib.colormaps.get_cmap("tab10")
colors = [cmap(i / len(personas)) for i in range(len(personas))]

persona_aspect_means = {}
for persona in personas:
    persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
    means = {}
    for aspect in ASPECTS:
        agg_scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in persona_entries
            if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        means[aspect] = np.mean(agg_scores) if agg_scores else 0
    persona_aspect_means[persona] = means

x = np.arange(len(ASPECTS))

fig_bar, ax_bar = plt.subplots(figsize=(fig_width, 5))

for i, (persona, means) in enumerate(persona_aspect_means.items()):
    values = [means[a] for a in ASPECTS]
    offset = (i - n_personas / 2 + 0.5) * width
    bars = ax_bar.bar(x + offset, values, width,
                      label=persona.replace("_", " ").title(),
                      color=colors[i], alpha=0.85)
    for bar, val in zip(bars, values):
        ax_bar.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                    f"{val:.2f}", ha="center", va="bottom", fontsize=8)

ax_bar.set_xticks(x)
ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
ax_bar.set_ylim(0.5, 5.5)
ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
ax_bar.set_ylabel("Average score over all instances")
ax_bar.set_title("Average Aggregate Scores per Aspect & Persona", fontweight="bold")
ax_bar.legend()
ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig_bar.tight_layout()
fig_bar.savefig("visualisations/evaluation/evaluation_summary_bar.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_summary_bar.svg")
plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar.svg

# %% [markdown]
# ### Plot 3: Average aggregate score per aspect

# %%
# ---------------------------------------------------------------------------
# PLOT 3 — Single bar chart: average aggregate score per aspect
# Averaged across all instances AND all personas — the headline result
# ---------------------------------------------------------------------------
aspect_means = {}
aspect_sems  = {}

for aspect in ASPECTS:
    scores = [
        e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
        for e in log_evaluated
        for persona in personas
        if persona in e.get("evaluations", {})
        and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
    ]
    aspect_means[aspect] = np.mean(scores)
    aspect_sems[aspect]  = np.std(scores, ddof=1) / np.sqrt(len(scores))

colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
fig, ax = plt.subplots(figsize=(5, 5))

x = np.arange(len(ASPECTS))
bars = ax.bar(
    x,
    [aspect_means[a] for a in ASPECTS],
    yerr=[aspect_sems[a] for a in ASPECTS],
    color=colors_aspects,
    alpha=0.85,
    capsize=5,
    width=0.5,
)
for bar, aspect in zip(bars, ASPECTS):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + aspect_sems[aspect] + 0.08,
        f"{aspect_means[aspect]:.2f}",
        ha="center", va="bottom", fontsize=11, fontweight="bold"
    )

ax.set_xticks(x)
ax.set_xticklabels([a.capitalize() for a in ASPECTS], fontsize=12)
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Average aggregate score (1–5)", fontsize=11)
ax.set_title("Average Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_headline.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_headline.svg")
plt.close(fig)
# Out:
# Saved aggregate_headline.svg

# %% [markdown]
# ### Plot 4: Per persona and instance comparison between llm judges

# %%
short_models = [m.split("/")[-1] for m in MODELS]
bar_width    = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, model in enumerate(MODELS):
            short_model = short_models[k]
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(MODELS) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_model,
                color=colors[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors[k], label=short_models[k])
        for k in range(len(MODELS))
    ]
    fig.legend(handles=handles, title="Judge Model", fontsize=8,
               loc="lower center", ncol=len(MODELS),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-LLM Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_llm_scores_{persona}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_llm_scores_doctor.svg
# Saved visualisations/evaluation/evaluation_llm_scores_doctor_elaborate.svg
# Saved visualisations/evaluation/evaluation_llm_scores_expert_judge.svg
# Saved visualisations/evaluation/evaluation_llm_scores_patient.svg
# Saved visualisations/evaluation/evaluation_llm_scores_patient_elaborate.svg

# %% [markdown]
# ### Plot 5: Per llm judge and instance comparison between personas

# %%
short_personas = [p.replace("_", " ").title() for p in personas]
bar_width      = 0.15
colors_p = ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B2"]

for model in MODELS:
    short_model = model.split("/")[-1]

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, persona in enumerate(personas):
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(personas) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_personas[k],
                color=colors_p[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors_p[k], label=short_personas[k])
        for k in range(len(personas))
    ]
    fig.legend(handles=handles, title="Persona", fontsize=8,
               loc="lower center", ncol=len(personas),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-Persona Scores — {short_model}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_persona_scores_{short_model}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_persona_scores_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_persona_scores_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_persona_scores_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_persona_scores_grok-4.20.svg

# %% [markdown]
# ####    Plot 5b: Aggregate scores per persona

# %%
# ---------------------------------------------------------------------------
# PLOT 5b — Aggregate scores per instance, coloured by persona
# 3 subplots (one per aspect), one figure total
# Replaces the per-persona loop with a single comparable figure
# ---------------------------------------------------------------------------
colors_p = ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B2"]
bar_width = 0.15  # Changed from 0.25 to 0.15 for more spacing

# Matched figsize to your second plot (14 width) to ensure identical scaling
fig, axes = plt.subplots(len(ASPECTS), 1,
                         figsize=(14, 5 * len(ASPECTS)),
                         sharey=True)

if len(ASPECTS) == 1:
    axes = [axes]

for ax, aspect in zip(axes, ASPECTS):
    x_positions = np.arange(len(instances))

    for k, persona in enumerate(personas):
        persona_entries = {e["instance_index"]: e for e in log_evaluated
                           if persona in e.get("evaluations", {})}
        scores = []
        for instance in instances:
            entry = persona_entries.get(instance)
            if entry:
                val = entry["evaluations"][persona].get(
                    aspect, {}).get("aggregate_score")
                scores.append(val if val is not None else 0)
            else:
                scores.append(0)

        offset = (k - len(personas) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=persona.replace("_", " ").title(),
            color=colors_p[k % len(colors_p)],
            alpha=0.85,
        )
        
        for bar, score in zip(bars, scores):
            if score > 0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.05,
                    f"{score:.1f}",
                    ha="center", va="bottom", fontsize=7
                )

    ax.set_xticks(x_positions)
    # Replaced rotation=45 with flat text to match your second plot, 
    # but you can add it back if your labels overlap
    ax.set_xticklabels([f"#{inst}" for inst in instances],
                       fontsize=9) 
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("Instance")
    ax.set_ylabel("Aggregate score (1–5)")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

handles = [
    mpatches.Patch(color=colors_p[k % len(colors_p)],
                   label=personas[k].replace("_", " ").title())
    for k in range(len(personas))
]
fig.legend(handles=handles, title="Persona", fontsize=8,
           loc="lower center", ncol=len(personas),
           bbox_to_anchor=(0.5, -0.05))

fig.suptitle(
    "Aggregate Scores per Instance & Persona",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_persona_per_instance.svg",
            dpi=150, bbox_inches="tight")
print("Saved aggregate_persona_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_persona_per_instance.svg

# %% [markdown]
# ### Plot 6: All metrics averaged per Persona, Judge, Instance

# %%
n_cols = 4
n_rows = math.ceil(len(instances) / n_cols)
short_models = [m.split("/")[-1] for m in MODELS]
bar_width = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6 * n_cols, 5 * n_rows), sharey=True)
axes_flat  = axes.flatten()

for ax in axes_flat[len(instances):]:
    ax.set_visible(False)

for ax, instance in zip(axes_flat, instances):
    x_positions = np.arange(len(personas))

    for k, model in enumerate(MODELS):
        short_model = short_models[k]
        scores = []

        for persona in personas:
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            entry = persona_entries.get(instance)
            if entry:
                aspect_scores = []
                for aspect in ASPECTS:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    if score is not None:
                        aspect_scores.append(score)
                scores.append(np.mean(aspect_scores) if aspect_scores else 0)
            else:
                scores.append(0)

        offset = (k - len(MODELS) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=short_model,
            color=colors[k],
            alpha=0.85,
        )

        for bar, score in zip(bars, scores):
            if score > 0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.05,
                    f"{score:.1f}",
                    ha="center", va="bottom", fontsize=6
                )

    ax.set_xticks(x_positions)
    ax.set_xticklabels(
        [p.replace("_", " ").title() for p in personas],
        fontsize=8
    )
    ax.set_title(f"Instance #{instance}", fontweight="bold", fontsize=10)
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

for ax in axes_flat[::n_cols]:
    ax.set_ylabel("Avg. score across all aspects")

handles = [
    mpatches.Patch(color=colors[k], label=short_models[k])
    for k in range(len(MODELS))
]
fig.legend(handles=handles, title="Judge Model", fontsize=8,
            loc="lower center", ncol=len(MODELS),
            bbox_to_anchor=(0.5, -0.02))

fig.suptitle(
    "Average score across all aspects per Persona, Judge and Instance\n"
    "(faithfulness, helpfulness and plausibility averaged)",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/evaluation_faceted.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_faceted.svg")
plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_faceted.svg

# %% [markdown]
# ### Plot 7: Score distribution per judge across all aspects and personas

# %%
short_models = [m.split("/")[-1] for m in MODELS]

fig, axes = plt.subplots(1, len(MODELS), figsize=(4 * len(MODELS), 4), sharey=True)

for ax, model in zip(axes, MODELS):
    short_model = model.split("/")[-1]
    scores = []

    for e in log_evaluated:
        for persona in personas:
            if persona not in e.get("evaluations", {}):
                continue
            for aspect in ASPECTS:
                data = e["evaluations"][persona].get(aspect, {}).get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                if score is not None:
                    scores.append(score)

    ax.hist(scores, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
            color="#4C72B0", edgecolor="white", alpha=0.85)
    ax.set_title(short_model, fontweight="bold", fontsize=9)
    ax.set_xlabel("Score")
    ax.set_ylabel("Count" if ax == axes[0] else "")
    ax.set_xticks([1, 2, 3, 4, 5])
    ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig.suptitle("Score Distribution per Judge (all aspects & personas)",
             fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/score_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/score_distribution.svg")
# Out:
# Saved visualisations/evaluation/score_distribution.svg

# %% [markdown]
# ####    Plot 7b: Aggregate score distribution

# %%
# ---------------------------------------------------------------------------
# PLOT 7b — Distribution of aggregate scores across all instances,
# aspects and personas — shows overall calibration of the pipeline
# ---------------------------------------------------------------------------
all_agg_scores = [
    e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
    for e in log_evaluated
    for persona in personas
    if persona in e.get("evaluations", {})
    for aspect in ASPECTS
    if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
]

fig, ax = plt.subplots(figsize=(5, 4))
ax.hist(
    all_agg_scores,
    bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
    color="#4C72B0", edgecolor="white", alpha=0.85
)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xlabel("Aggregate score", fontsize=11)
ax.set_ylabel("Count", fontsize=11)
ax.set_title("Aggregate Score Distribution", fontweight="bold")
ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

mean_agg = np.mean(all_agg_scores)
ax.axvline(x=mean_agg, color="#C44E52", linestyle="-", linewidth=1.5, label=f"Mean = {mean_agg:.2f}")
ax.legend(fontsize=9)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_distribution.svg")
plt.close(fig)
# Out:
# Saved aggregate_distribution.svg

# %% [markdown]
# ### Plot 8: Per instance aggregate scores per aspect

# %%
# ---------------------------------------------------------------------------
# PLOT 8 — Per-instance aggregate scores per aspect
# Aggregate_score averaged across personas, shown per instance
# Primary result figure: shows narrative quality across the 20 instances
# ---------------------------------------------------------------------------
colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
bar_width = 0.25

x_positions = np.arange(len(instances))
fig, ax = plt.subplots(figsize=(max(12, len(instances) * 0.7), 5))

for k, (aspect, color) in enumerate(zip(ASPECTS, colors_aspects)):
    values = [instance_aspect_means[inst][aspect] for inst in instances]
    offset = (k - len(ASPECTS) / 2 + 0.5) * bar_width
    bars = ax.bar(
        x_positions + offset, values,
        width=bar_width, label=aspect.capitalize(),
        color=color, alpha=0.85
    )
    for bar, val in zip(bars, values):
        if not np.isnan(val):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.1f}", ha="center", va="bottom", fontsize=7
            )

ax.set_xticks(x_positions)
ax.set_xticklabels([f"#{inst}" for inst in instances], fontsize=9, rotation=45, ha="right")
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Aggregate score (averaged across personas)", fontsize=10)
ax.set_xlabel("Instance", fontsize=10)
ax.set_title("Per-Instance Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.legend(title="Aspect", fontsize=9, loc="lower left")
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_per_instance.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_per_instance.svg
