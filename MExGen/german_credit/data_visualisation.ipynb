# %% [markdown]
# # 1. Imports

# %%
import pickle
import glob
import re
import os
import json
import textwrap
import math
from types import SimpleNamespace
from collections import defaultdict
from itertools import cycle

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns

from mexgen_story import MExGenStory
import config

# %%
# --- Load attribution data from pkl files ---
pkl_files = sorted(glob.glob("mexgen_results/mexgen_results_instance_*.pkl"))

dfs = {}

for fname in pkl_files:
    with open(fname, "rb") as f:
        mexgen_results = pickle.load(f)

    data       = mexgen_results["output_dict_words"]
    units      = data["attributions"]["units"]
    scores     = data["attributions"]["bert"]
    unit_types = data["attributions"]["unit_types"]

    attribution_df = pd.DataFrame([
        {"token": unit.strip(), "attribution_score": round(float(score), 4)}
        for unit, score, utype in zip(units, scores, unit_types)
        if utype == "w"
    ]).assign(position=lambda df: range(len(df))) \
      .sort_values("attribution_score", ascending=False) \
      .reset_index(drop=True)

    instance_id = int(re.search(r"instance_(\d+)", fname).group(1))
    dfs[instance_id] = attribution_df

# --- Load log (narratives + evaluations) ---
with open(config.LOG_JSON, "r") as f:
    log = json.load(f)

# Convenience lookup: {instance_id (int): log entry}
log_by_instance = {e["instance_index"]: e for e in log}

# Filter to evaluated entries only
log_evaluated = [e for e in log if "evaluations" in e]

instances = sorted(set(e["instance_index"] for e in log_evaluated))
personas  = sorted(set(
    p for e in log_evaluated
    for p in e["evaluations"].keys()
))

ASPECTS = config.JUDGE_ASPECTS
MODELS  = config.JUDGE_MODELS

# %% [markdown]
# # 2. Print all attribution scores

# %%
for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    print(df[["token", "attribution_score"]].to_string(index=False))
# Out:
# === instance_0 ===
#    token  attribution_score
#      Age             1.0000
# critical             0.5933
#   single             0.3589
#       67             0.3446
#  unknown             0.2882
# existing             0.0247
# Personal             0.0182
#    other             0.0136
#   Credit             0.0116
#  account             0.0039
#  account            -0.0008
#      Job            -0.0052
#     male            -0.0079
#  savings            -0.0091
#        6            -0.0164
#  credits            -0.0168
#      and            -0.0191
#  history            -0.0194
#   Credit            -0.0195
#  account            -0.0197
#      sex            -0.0280
#     1169            -0.0316
# employee            -0.0335
#       no            -0.0361
#    bonds            -0.0378
#   amount            -0.0391
#  Savings            -0.0409
#   status            -0.0419
#  skilled            -0.0473
# official            -0.0510
# Duration            -0.0520
#
# === instance_1 ===
#     token  attribution_score
#  Duration             1.0000
#    Credit             0.6238
#   married             0.4785
#      5951             0.4453
#    Credit             0.4361
#        DM             0.4339
#   account             0.4172
#   credits             0.3840
#      back             0.3743
#    amount             0.3636
#       100             0.3626
#   skilled             0.3560
#      duly             0.3535
#       and             0.3518
#     bonds             0.3437
#   Savings             0.3293
#       sex             0.3259
#        48             0.2954
#        22             0.2923
#    female             0.2505
#       Job             0.2320
#       Age             0.2245
#  official             0.2220
#  Personal             0.1203
#  divorced             0.0698
# separated             0.0563
#    status             0.0439
#  existing            -0.0174
#  employee            -0.0510
#      paid            -0.1010
#   history            -0.2636
#
# === instance_4 ===
#    token  attribution_score
#    delay             1.0000
#  history             0.2214
#    bonds             0.2160
#     male             0.2001
#       in             0.1824
# official             0.0234
#       in             0.0159
#      Age             0.0100
#      and             0.0095
#      sex             0.0088
#  skilled             0.0086
# employee             0.0084
#  account             0.0073
#       53             0.0063
#  Savings             0.0032
#      100             0.0028
#   amount             0.0021
#     4870            -0.0041
#       24            -0.0236
#     past            -0.0241
#   paying            -0.0244
#   Credit            -0.0298
#      off            -0.0308
#      Job            -0.0348
#   Credit            -0.0353
#   single            -0.0372
# Personal            -0.0413
# Duration            -0.0438
#      the            -0.0459
#       DM            -0.0486
#   status            -0.0509
#
# === instance_9 ===
#      token  attribution_score
#   employed             0.0986
#    account             0.0874
#    Savings             0.0803
#   critical             0.0749
#      other             0.0588
#        Age             0.0442
#     amount             0.0394
#     Credit             0.0349
#        100             0.0333
#        sex             0.0202
#        and            -0.0197
#    widowed            -0.0222
#      bonds            -0.0242
#       self            -0.0295
#         DM            -0.0296
#   Personal            -0.0321
#       male            -0.0373
#    account            -0.0742
#     status            -0.0788
#   existing            -0.1068
#    credits            -0.1184
#    married            -0.1233
#     Credit            -0.1287
#     highly            -0.1575
#   Duration            -0.2025
#  qualified            -0.2064
#        Job            -0.2399
#    history            -0.5135
#         28            -0.6963
#       5234            -0.7943
#         30            -0.8770
# management            -1.0000
#
# === instance_17 ===
#    token  attribution_score
#       30             1.0000
# Duration             0.9288
#     paid             0.6275
#  history             0.6067
#      all             0.5149
# employee             0.4828
#   amount             0.4657
#  skilled             0.4655
#   Credit             0.4465
#   status             0.4275
#     8072             0.3965
#      sex             0.3834
# Personal             0.3799
#       25             0.3767
#      Job             0.3461
#  credits             0.3422
#  account             0.3238
#   single             0.2961
#     duly             0.2959
#  savings             0.2853
#      and             0.2817
#    bonds             0.2784
# official             0.2718
#       no             0.2672
#      Age             0.2572
#     male             0.2276
#  account             0.2257
#  unknown             0.2234
#   Credit             0.1994
#       no             0.1451
#     back             0.0605
#  Savings             0.0578
#
# === instance_29 ===
#    token  attribution_score
#    delay             1.0000
#       in             0.4461
#       in             0.4287
#     male             0.0230
#   single             0.0227
#      Age             0.0105
#    bonds             0.0088
#   Credit             0.0071
# Duration             0.0051
#     6836             0.0002
#      off            -0.0023
#       63            -0.0037
#   paying            -0.0049
#     past            -0.0067
#   amount            -0.0101
#       60            -0.0105
#  Savings            -0.0114
#       DM            -0.0197
#   status            -0.0217
#      sex            -0.0236
#      Job            -0.0288
# official            -0.0308
#      the            -0.0316
#  account            -0.0321
#      and            -0.0384
#  skilled            -0.0405
# employee            -0.0443
# Personal            -0.0455
#   Credit            -0.0462
#  history            -0.0486
#      100            -0.0521
#
# === instance_55 ===
#     token  attribution_score
#   history             0.0955
#    status             0.0704
#  Duration             0.0603
#        26             0.0462
#      duly             0.0355
#         6             0.0352
#   unknown             0.0243
#    Credit             0.0224
#       all             0.0156
#   account             0.0135
#       783             0.0097
#   credits             0.0094
#        at             0.0072
#      bank             0.0028
#    amount            -0.0107
#      back            -0.0148
#   savings            -0.0162
#  Personal            -0.0196
#       sex            -0.0208
#      male            -0.0210
#     bonds            -0.0302
#      paid            -0.0389
#    Credit            -0.0402
#       and            -0.0467
#       Age            -0.0585
#   Savings            -0.1056
#      this            -0.1637
#        no            -0.2236
#  resident            -0.2844
#    single            -0.3493
#   account            -0.4906
#       Job            -0.8919
# unskilled            -1.0000
#
# === instance_95 ===
#    token  attribution_score
#   Credit             0.2846
#    bonds             0.0015
#  credits            -0.0274
#   status            -0.0558
#     back            -0.0576
#      and            -0.0625
#  account            -0.1003
# employee            -0.1107
#   amount            -0.1145
#  Savings            -0.1181
#     duly            -0.1368
#  skilled            -0.1511
#   Credit            -0.1692
#      all            -0.1779
#       DM            -0.1815
#   single            -0.1903
# official            -0.1915
#       58            -0.1934
#     male            -0.2087
#     paid            -0.2114
#    15945            -0.2137
#      sex            -0.2214
#      Job            -0.2708
#      Age            -0.2731
#      100            -0.2965
#       54            -0.3362
#       no            -0.3424
# Personal            -0.3493
#  history            -0.5981
# Duration            -1.0000
#
# === instance_107 ===
#    token  attribution_score
#  history             0.4571
#       12             0.1874
#     6078             0.1789
#  credits             0.1010
#   Credit             0.0691
#  skilled             0.0348
#     back             0.0106
# official             0.0065
#      and            -0.0031
#       DM            -0.0152
#       32            -0.0157
#     male            -0.0452
#     duly            -0.0546
#      100            -0.0647
#     paid            -0.0746
#    bonds            -0.0868
#      sex            -0.0923
# Personal            -0.1025
#      Age            -0.1429
#      Job            -0.1455
#   single            -0.1477
#  account            -0.1539
#   status            -0.1564
#   amount            -0.1772
#  Savings            -0.2483
# employee            -0.2807
# existing            -0.3770
# Duration            -0.4737
#   Credit            -1.0000
#
# === instance_134 ===
#     token  attribution_score
#   history             0.2355
#        60             0.2214
#   credits             0.0626
#      back            -0.0654
#     10144            -0.1176
#   Savings            -0.1351
#   account            -0.1449
#  official            -0.1457
# separated            -0.1579
#       Job            -0.1626
#    status            -0.1680
#       500            -0.1715
#    female            -0.1942
#   married            -0.1964
#    Credit            -0.2173
#   skilled            -0.2250
#        DM            -0.2273
#       sex            -0.2273
#    amount            -0.2426
#  Personal            -0.2500
#       100            -0.2569
#  divorced            -0.2616
#     bonds            -0.2643
#  employee            -0.2741
#      duly            -0.2803
#       Age            -0.2845
#        21            -0.3039
#       and            -0.3107
#    Credit            -0.3549
#      paid            -0.3704
#  existing            -0.4205
#  Duration            -1.0000

# %% [markdown]
# for reference: {attribution_table} which gets added to the narrative prompt (mexgen_story.py) and faithfulness evaluation prompt (evaluation_prompts.py)

# %%
storyteller = MExGenStory(api_key="dummy", model_name="dummy")

pkl_path = "mexgen_results/mexgen_results_instance_0.pkl"
with open(pkl_path, "rb") as f:
    mexgen_results = pickle.load(f)

attribution_df = storyteller.build_attribution_df(
    mexgen_results["output_dict_words"],
    mexgen_results["scalarizer"],
)
print(attribution_df.to_string(index=False))
# Out:
#     token  attribution_score
#       Age           1.000000
# critical            0.593326
#    single           0.358908
#        67           0.344611
#   unknown           0.288213
#  existing           0.024695
# Personal            0.018223
#    other            0.013561
#   Credit            0.011636
#   account           0.003898
#   account          -0.000784
#       Job          -0.005199
#      male          -0.007906
#  savings           -0.009121
#         6          -0.016403
#  credits           -0.016809
#      and           -0.019054
#   history          -0.019390
#   Credit           -0.019504
#   account          -0.019708
#       sex          -0.028037
#      1169          -0.031617
#  employee          -0.033467
#       no           -0.036073
#     bonds          -0.037818
#    amount          -0.039061
#  Savings           -0.040886
#   status           -0.041877
#  skilled           -0.047260
#  official          -0.051017
#  Duration          -0.052017

# %% [markdown]
# ## 2b. Print all evaluations

# %%
for entry in log_evaluated:
    instance_id = entry["instance_index"]
    print(f"\n=== instance_{instance_id} ===")
    rows = []
    for persona, aspects in entry["evaluations"].items():
        for aspect, data in aspects.items():
            agg = data.get("aggregate_score")
            rows.append({"persona": persona, "aspect": aspect, "aggregate_score": agg})
    df_agg = pd.DataFrame(rows)
    print(df_agg.to_string(index=False))

# %% [markdown]
# # 3. Print everything for specific instance

# %%
instance_id = 55

entry = log_by_instance[instance_id]
df = dfs[instance_id]

print(f"=== Instance {instance_id} ===")
print(f"\nLLM response: '{entry['baseline_response']}'")

print(f"\nAttributions (sorted by influence):")
print(df[["token", "attribution_score"]].to_string(index=False))

print(f"\nNarrative:")
print(textwrap.fill(entry["story"], width=150))

print(f"\nEvaluation scores (final score per judge):")
for persona, aspects in entry.get("evaluations", {}).items():
    print(f"\n  {'='*50}")
    print(f"  {persona.replace('_', ' ').title()}")
    print(f"  {'='*50}")
    for aspect, models in aspects.items():
        agg = models.get("aggregate_score")
        print(f"    {aspect.capitalize():<15} aggregate: {agg}")
        for model in config.JUDGE_MODELS:
            data = models.get(model, {})
            score = data.get("final_score") if isinstance(data, dict) else None
            short_model = model.split("/")[-1]
            print(f"      {short_model:<35} {score}")
# Out:
# === Instance 55 ===
#
# LLM response: 'Good'
#
# Attributions (sorted by influence):
#     token  attribution_score
#   history             0.0955
#    status             0.0704
#  Duration             0.0603
#        26             0.0462
#      duly             0.0355
#         6             0.0352
#   unknown             0.0243
#    Credit             0.0224
#       all             0.0156
#   account             0.0135
#       783             0.0097
#   credits             0.0094
#        at             0.0072
#      bank             0.0028
#    amount            -0.0107
#      back            -0.0148
#   savings            -0.0162
#  Personal            -0.0196
#       sex            -0.0208
#      male            -0.0210
#     bonds            -0.0302
#      paid            -0.0389
#    Credit            -0.0402
#       and            -0.0467
#       Age            -0.0585
#   Savings            -0.1056
#      this            -0.1637
#        no            -0.2236
#  resident            -0.2844
#    single            -0.3493
#   account            -0.4906
#       Job            -0.8919
# unskilled            -1.0000
#
# Narrative:
# When the AI evaluated this loan application, it acted like a detective focusing more on a person's track record than their current job status. The
# strongest positive influence on the "Good" rating was the applicant's **history**, specifically the fact that they had paid back past debts **duly**.
# The AI also placed significant weight on the short **Duration** of the loan—just **6** months—viewing a quick repayment period as a lower risk.
# Interestingly, the model reached its positive verdict despite several "red flags" that usually worry lenders. Words like **unskilled**, **Job**, and
# **single** carried massive negative scores, meaning they actively tried to pull the model toward a "Bad" rating. Even the lack of financial reserves,
# signaled by the word **no** in the savings section, weighed heavily against the applicant. Ultimately, the AI’s decision was a tug-of-war where the
# strength of a clean financial **history** outweighed the instability of an **unskilled** job. This reveals that the model prioritizes past consistency
# over current social or professional standing.  **Summary:** The AI predicted a "Good" risk because the applicant's perfect repayment history and short
# loan duration outweighed the significant negative signals from their unskilled job status and lack of savings.
#
# Evaluation scores (final score per judge):
#
#   ==================================================
#   Expert Judge
#   ==================================================
#     Faithfulness    aggregate: 3.25
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   3
#       grok-4.20                           1
#     Helpfulness     aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#
#   ==================================================
#   Bank Client
#   ==================================================
#     Faithfulness    aggregate: 3.875
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              3.5
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Helpfulness     aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#
#   ==================================================
#   Bank Officer
#   ==================================================
#     Faithfulness    aggregate: 5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Helpfulness     aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 4.5
#       gpt-5.4                             4
#       gemini-3.1-pro-preview              5
#       claude-sonnet-4.6                   4
#       grok-4.20                           5

# %% [markdown]
# # 4. Print narratives

# %%
for entry in log:
    print(f"=== Instance: {entry['instance_index']} ===")
    print(f"LLM response: '{entry['baseline_response']}'")
    print(f"Narrative:\n{textwrap.fill(entry['story'], width=150)}")
    print()
# Out:
# === Instance: 0 ===
# LLM response: 'Bad'
# Narrative:
# When an AI looks at a loan application, it doesn't "think" like a human banker; instead, it reacts to specific triggers that carry the most
# mathematical weight. In this case, although the applicant asked for a very small loan over a short period, the model largely ignored those stable
# financial details. The absolute strongest driver for the "Bad" credit rating was the word **Age**, followed closely by the specific number **67**,
# suggesting the model flagged being a senior citizen as a primary risk factor. The AI also fixated on the words **critical** and **unknown**, reacting
# poorly to a "critical" past credit history and "unknown" savings. Interestingly, while the applicant is a "skilled employee," the words describing his
# professional stability had almost no impact on the decision. Even his status as **single** pushed the model further toward a negative result,
# outweighing the actual dollar amounts involved. Ultimately, the model’s "Bad" verdict wasn't based on the size of the loan, but on a rigid focus on
# age and past credit labels.  **Summary:** The AI reached its decision by prioritizing demographic triggers like age and marital status over the actual
# financial specifics of the loan. This reveals that the model views being an older, single applicant with a "critical" history as an automatic
# disqualifier, regardless of their current job or the small amount of credit requested.
#
# === Instance: 1 ===
# LLM response: 'Good'
# Narrative:
# When the AI evaluated this loan application, it didn't just look at the numbers; it acted like a detective weighing the importance of specific clues.
# Surprisingly, the word **Duration** was the single most powerful factor, suggesting the model prioritized the timeline of the loan above all else to
# anchor its decision. It found great confidence in the applicant’s **Credit** history and the phrase **back duly**, seeing a pattern of reliability
# that signaled a "Good" risk. Interestingly, the model was also heavily swayed by the applicant’s personal context, particularly the word **married**,
# which it likely associated with financial stability. Even the specific loan amount of **5951** DM and her status as a **skilled** worker acted as
# strong green flags in the AI's logic. On the other hand, the word **history** actually gave the model "pause" or negative doubt, though not enough to
# flip the final verdict. By connecting these dots, we see the AI didn't just calculate a score; it built a profile based on stability, repayment
# keywords, and the specific timeframe of the request.  **Summary:** The AI reached a "Good" decision primarily by focusing on the loan's duration and
# keywords associated with successful past repayments, like "Credit" and "back duly." While most factors were positive, the model showed that it weights
# specific vocabulary—like marital status and job skill level—as heavily as the actual financial figures.
#
# === Instance: 107 ===
# LLM response: 'Good'
# Narrative:
# When the Artificial Intelligence looked at this loan applicant, it acted more like a pattern-recognizer than a human banker. To decide the applicant
# was a "Good" risk, the model focused most intensely on the word **history**, seeing the track record of past behavior as the strongest green light for
# approval. Interestingly, the model was also highly influenced by the specific numbers **12** (the duration) and **6078** (the amount), suggesting that
# this specific combination of a short timeframe and a moderate loan size fits its internal template for a safe bet. However, the process wasn't
# entirely intuitive; the word **Credit** actually had a massive negative score, meaning its presence alone made the model hesitate or feel less
# "certain" about its final answer. Other details that a human might find vital, like the applicant being a "skilled employee" or their "age," barely
# moved the needle at all. It appears the model prioritized the "what" and the "how much" over the "who." Even though terms like "Savings" and
# "Duration" pushed against a positive result, they were ultimately drowned out by the positive momentum of that solid "history." In short, the model
# saw a specific financial pattern it liked—short-term and historically backed—and ignored the personal biography of the applicant to reach its verdict.
# **Summary:** The model’s "Good" rating was primarily driven by the applicant’s positive credit history and the specific loan amounts, while it
# surprisingly viewed the general labels for "Credit" and "Duration" as points of uncertainty.
#
# === Instance: 134 ===
# LLM response: 'Good'
# Narrative:
# When an AI looks at a loan application, it doesn't "think" like a human banker; instead, it weighs specific words like components on a scale. In this
# case, the AI predicted the applicant was a "Good" risk, but the explanation reveals a surprising tug-of-war behind that decision. The word
# **"history"** was the strongest positive driver, suggesting the model latched onto the concept of past reliability as its primary reason for approval.
# Curiously, the number **"60"** (the loan duration) also pushed strongly toward a "Good" rating, perhaps because the model associates longer
# commitments with established trust.  However, almost every other detail—like the applicant’s young **"Age"** of **"21"** or their status as an
# **"existing"** customer—actually pulled the model toward a "Bad" rating. Most strikingly, the word **"Duration"** had the most extreme negative
# impact, indicating that the very idea of a long-term loan initially made the model highly skeptical. The final "Good" result wasn't a unanimous vote,
# but rather a narrow victory where the positive weight of a clean credit **"history"** managed to outvote a sea of doubts about the applicant's youth
# and the loan's length. Essentially, the model saw a shaky profile but decided that a solid track record was the one factor that mattered most.
# **Summary:** The AI approved the loan because it prioritized "history" above all else, even though it viewed the applicant's young age and the long
# loan duration as significant red flags.
#
# === Instance: 17 ===
# LLM response: 'Good'
# Narrative:
# When a Large Language Model evaluates a loan application, it doesn’t "think" like a human banker; instead, it looks for patterns and keywords that
# give it the most confidence in an answer. In this case, the model’s decision to label the applicant as a "Good" risk was most heavily anchored by the
# specific timeframe of the loan, with the word **"Duration"** and the value **"30"** acting as the strongest green lights. Interestingly, while the
# loan amount and age played minor roles, the model was highly swayed by the phrase **"paid back history,"** seeing these words as a powerful signal of
# reliability. It essentially prioritized the fact that previous debts were handled **"duly"** and the applicant held a **"skilled employee"** status
# over details like how much money was actually in their savings account. Even though some information was "unknown," the model leaned into the positive
# professional and historical markers to tip the scales toward approval. This process shows that the AI isn't weighing every piece of data equally; it
# focuses on specific "anchor" words that it has learned to associate with financial stability.  **Summary:** The model predicted a "Good" credit risk
# primarily because it was highly sensitive to the loan's **Duration** and the applicant’s **historical track record** of paying back debt. While the
# technical "skynet" might seem mysterious, this analysis reveals it functioned like a digital scout, prioritizing professional status and past
# reliability above all else.
#
# === Instance: 29 ===
# LLM response: 'Bad'
# Narrative:
# When the AI looked at this loan application, it didn’t weigh every detail equally; instead, it acted like a scout searching for red flags. While the
# applicant’s age, job title, and specific loan amount seemed like important context to a human, the model’s "C-LIME" analysis reveals that these
# factors barely moved the needle. The overwhelming driver for the "Bad" rating was a single, powerful word: **"delay."** This one word carried the
# maximum possible influence, functioning as a deal-breaker that overshadowed the applicant’s long career as a skilled official.  Interestingly, the
# model was also heavily fixated on the word **"in,"** likely because it linked that "delay" to the applicant's "past" behavior, creating a definitive
# pattern of risk. Other details, such as the specific savings amount of "100" DM or the status of being a "skilled employee," actually tried to push
# the model toward a positive result, but their influence was tiny compared to the weight of the past payment issues. Even the 60-month duration and the
# applicant's older age were largely ignored in favor of that one critical linguistic trigger. Ultimately, the story of this decision isn't about a
# complex financial calculation, but about how a single word can dominate an AI's logic.  **Summary:** The AI's "Bad" prediction was almost entirely
# triggered by the word "delay" in the credit history, effectively ignoring the applicant's age, job, and loan amount in its final decision.
#
# === Instance: 4 ===
# LLM response: 'Bad'
# Narrative:
# When the AI looked at this loan application, it acted less like a nuanced banker and more like a high-speed pattern matcher focused on red flags. By
# using a "C-LIME" analysis—a method that hides parts of the text to see what changes the result—we discovered that the word **"delay"** was the
# absolute driving force, holding the maximum influence over the decision. While the applicant’s age and job title were present, the model effectively
# stopped caring about those details once it saw a history of late payments. Interestingly, the model also placed significant weight on the words
# **"bonds"** and **"male,"** suggesting it may be relying on internal biases or rigid associations between gender, asset types, and financial
# stability. Traditional factors like the specific loan amount or the duration of the debt had almost no impact, essentially becoming "invisible" to the
# AI's logic. This reveals that the model didn't weigh the whole profile equally; it fixated on a few negative keywords to trigger its "Bad" rating.
# Even the applicant's status as a "skilled employee" couldn't overcome the massive weight the AI placed on that single mention of a past payment delay.
# **Summary:** The AI's "Bad" prediction was almost entirely triggered by the word "delay," showing that it prioritizes past mistakes over current
# stability. Its reliance on gender and specific keywords over actual financial figures suggests a rigid, checklist-style logic rather than a holistic
# financial assessment.
#
# === Instance: 55 ===
# LLM response: 'Good'
# Narrative:
# When the AI evaluated this loan application, it acted like a detective focusing more on a person's track record than their current job status. The
# strongest positive influence on the "Good" rating was the applicant's **history**, specifically the fact that they had paid back past debts **duly**.
# The AI also placed significant weight on the short **Duration** of the loan—just **6** months—viewing a quick repayment period as a lower risk.
# Interestingly, the model reached its positive verdict despite several "red flags" that usually worry lenders. Words like **unskilled**, **Job**, and
# **single** carried massive negative scores, meaning they actively tried to pull the model toward a "Bad" rating. Even the lack of financial reserves,
# signaled by the word **no** in the savings section, weighed heavily against the applicant. Ultimately, the AI’s decision was a tug-of-war where the
# strength of a clean financial **history** outweighed the instability of an **unskilled** job. This reveals that the model prioritizes past consistency
# over current social or professional standing.  **Summary:** The AI predicted a "Good" risk because the applicant's perfect repayment history and short
# loan duration outweighed the significant negative signals from their unskilled job status and lack of savings.
#
# === Instance: 9 ===
# LLM response: 'Bad'
# Narrative:
# When an AI evaluates a loan application, it doesn't "think" like a human banker; instead, it weighs specific words like heavy stones on a scale. In
# this case, the AI labeled the applicant as a "Bad" risk, but the reasons behind that decision were surprisingly lopsided. While you might expect the
# loan’s specific details to be the main focus, the AI was most intensely fixated on the word **"management."** This single word acted as a massive
# weight, dragging the prediction toward "Bad," perhaps because the model associates high-level roles with volatile income or over-leverage in its
# training data.  Interestingly, the actual numbers—the **30**-month duration, the **5234** DM amount, and the age of **28**—were also strong drivers,
# yet they were outweighed by the job title and the phrase **"history."** On the other side of the scale, words like **"employed"** and **"savings"**
# tried to pull the model toward a "Good" rating, but their influence was tiny compared to the negative pull of the job description. The AI essentially
# ignored the applicant’s marital status and gender, focusing instead on a lopsided combination of a specific career tier and the loan's timeline. This
# reveals a "tunnel vision" effect, where a few specific labels can drown out more nuanced financial information. Ultimately, the AI's "Bad" verdict was
# less about a balanced financial review and more about a sharp, mathematical reaction to the word **"management."**  **Summary:** The model’s "Bad"
# rating was primarily driven by the applicant's job title ("management") and the specific duration of the loan, which far outweighed the positive
# influence of being employed or having savings.
#
# === Instance: 95 ===
# LLM response: 'Good'
# Narrative:
# When an AI assesses a loan, we assume it carefully weighs things like income or age, but the C-LIME analysis reveals a much more surprising process
# behind the decision to label this applicant "Good." In this case, the model’s prediction was overwhelmingly driven not by the applicant’s actual data,
# but by the labels and structure of the prompt itself. The word "Duration" was the single most influential factor, yet it acted as a massive negative
# weight, suggesting the model found the long 54-month term highly risky and nearly chose a "Bad" rating because of it. Similarly, the data categories
# like "history" and "Personal" features pulled the model toward a negative outlook, indicating that the AI viewed the applicant's specific
# profile—long-term debt, low savings, and older age—with significant "doubt." Paradoxically, the model stayed with a "Good" rating largely because of
# the word "Credit" at the very top of the prompt, which seemed to anchor the AI in its role as a professional scoring tool. Most of the specific
# numbers, like the age of 58 or the 15,945 DM amount, had relatively low influence compared to the structural headings of the form. Ultimately, the
# AI’s "Good" verdict was a narrow victory, emerging not from a glowing financial review, but from a complex tug-of-war where the formal context of the
# "Credit" task barely outweighed the deep concerns it had about the loan's "Duration."  **Summary:** The AI's decision was shaped more by the
# categories of the application than the specific numbers, with the long "Duration" almost triggering a rejection until the overarching "Credit" context
# nudged it toward a positive result.

# %% [markdown]
# # 5. Visualisations

# %% [markdown]
# ## 5.1 Attribution score plot of prompt

# %% [markdown]
# custom visualisation function

# %%
def print_colored_text(df, max_width=150):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["attribution_score"].abs().max()

    def get_color(value):
        # 2. Map the value so that 0 is exactly 0.5 (neutral)
        if max_abs == 0:
            norm_value = 0.5
        else:
            norm_value = (value + max_abs) / (2 * max_abs)
            
        if norm_value < 0.5:
            r = int(255 * (norm_value * 2))
            g = int(255 * (norm_value * 2))
            b = 255
        else:
            r = 255
            g = int(255 * (2 - norm_value * 2))
            b = int(255 * (2 - norm_value * 2))
        return r, g, b

    current_width = 0
    for _, row in df.iterrows():
        token = row["token"]
        token_width = len(token) + 1  # +1 for the space
        if current_width + token_width > max_width:
            print()
            current_width = 0
        r, g, b = get_color(row["attribution_score"])
        print(f"\033[38;2;{r};{g};{b}m{token}\033[0m", end=' ')
        current_width += token_width
    print()

def plot_colored_text(df, title="", max_width=0.95, fontsize=11, save_path=None):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["attribution_score"].abs().max()

    # Build lines by measuring real rendered text widths
    fig, ax = plt.subplots(figsize=(14, 2))
    renderer = fig.canvas.get_renderer()

    lines = []
    current_line = []
    current_width = 0.0

    for _, row in df.iterrows():
        # Measure the actual rendered width of this token
        t = ax.text(0, 0, row["token"] + " ", fontsize=fontsize, transform=ax.transAxes)
        bbox = t.get_window_extent(renderer=renderer)
        t.remove()
        token_width = bbox.width / fig.get_window_extent(renderer=renderer).width

        if current_line and current_width + token_width > max_width:
            lines.append(current_line)
            current_line = []
            current_width = 0.0
        current_line.append((row, token_width))
        current_width += token_width

    if current_line:
        lines.append(current_line)

    plt.close(fig)

    # Now draw the real figure
    num_lines = len(lines)
    fig, ax = plt.subplots(figsize=(14, num_lines * 0.5 + 1.5))
    ax.axis('off')

    y_step = 0.85 / (num_lines)
    y_pos = 0.95

    for line in lines:
        x_pos = 0.02
        for row, token_width in line:
            # 2. Map the value for the coolwarm colormap
            if max_abs == 0:
                norm_value = 0.5
            else:
                norm_value = (row["attribution_score"] + max_abs) / (2 * max_abs)
                
            color = plt.cm.coolwarm(norm_value)
            ax.text(x_pos, y_pos, row["token"], color=color, fontsize=fontsize,
                    ha='left', va='top', transform=ax.transAxes)
            x_pos += token_width
        y_pos -= y_step

    if title:
        ax.set_title(title, fontsize=13, pad=10)

    # 3. Update the colorbar to be strictly symmetrical (-max_abs to max_abs)
    sm = plt.cm.ScalarMappable(
        cmap=plt.cm.coolwarm, 
        norm=plt.Normalize(vmin=-max_abs, vmax=max_abs)
    )
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.05)
    cbar.set_label('C-LIME Attribution Score', fontsize=11)

    plt.tight_layout()
    
    # Save the figure if a path is provided
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        
    plt.show()

# %%
# 1. Update the folder path to include the 'attributions' subfolder
save_dir = os.path.join('visualisations', 'attributions')
os.makedirs(save_dir, exist_ok=True)

for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    df_ordered = df.sort_values("position")  # original sentence order

    # Print to terminal
    print_colored_text(df_ordered)
    
    # 2. Point the save_file to the new directory
    save_file = os.path.join(save_dir, f"attributions_{instance_id}.svg")

    # Plot and save
    plot_colored_text(df_ordered, title=f"instance_{instance_id}", save_path=save_file)
# Out:
# === instance_0 ===
# Duration 6 Credit history critical account other credits existing Credit amount 1169 Savings account bonds unknown no savings account Personal status
# and sex male single Age 67 Job skilled employee official
# === instance_1 ===
# Duration 48 Credit history existing credits paid back duly Credit amount 5951 Savings account bonds 100 DM Personal status and sex female divorced
# separated married Age 22 Job skilled employee official
# === instance_4 ===
# Duration 24 Credit history delay in paying off in the past Credit amount 4870 Savings account bonds 100 DM Personal status and sex male single Age 53
# Job skilled employee official
# === instance_9 ===
# Duration 30 Credit history critical account other credits existing Credit amount 5234 Savings account bonds 100 DM Personal status and sex male
# married widowed Age 28 Job management self employed highly qualified
# === instance_17 ===
# Duration 30 Credit history no credits all paid back duly Credit amount 8072 Savings account bonds unknown no savings account Personal status and sex
# male single Age 25 Job skilled employee official
# === instance_29 ===
# Duration 60 Credit history delay in paying off in the past Credit amount 6836 Savings account bonds 100 DM Personal status and sex male single Age 63
# Job skilled employee official
# === instance_55 ===
# Duration 6 Credit history all credits at this bank paid back duly Credit amount 783 Savings account bonds unknown no savings account Personal status
# and sex male single Age 26 Job unskilled resident
# === instance_95 ===
# Duration 54 Credit history no credits all paid back duly Credit amount 15945 Savings account bonds 100 DM Personal status and sex male single Age 58
# Job skilled employee official
# === instance_107 ===
# Duration 12 Credit history existing credits paid back duly Credit amount 6078 Savings account bonds 100 DM Personal status and sex male single Age 32
# Job skilled employee official
# === instance_134 ===
# Duration 60 Credit history existing credits paid back duly Credit amount 10144 Savings account bonds 100 500 DM Personal status and sex female
# divorced separated married Age 21 Job skilled employee official

# %% [markdown]
# ## 5.2 Narrative evaluation

# %%
os.makedirs("visualisations/evaluation", exist_ok=True)

# %% [markdown]
# ### Plot 1: Evaluation heatmaps

# %%
# ---------------------------------------------------------------------------
# Helper — extract scores from a single entry
# Returns: {aspect: {model: score}}
# ---------------------------------------------------------------------------
def extract_scores(entry: dict, persona: str) -> dict:
    scores = {}
    for aspect in ASPECTS:
        scores[aspect] = {}
        aspect_data = entry["evaluations"][persona].get(aspect, {})
        for model in MODELS:
            model_data = aspect_data.get(model, {})
            scores[aspect][model] = model_data.get("final_score", None)
    return scores

# %%
# ---------------------------------------------------------------------------
# PLOT 1 — Per-instance heatmaps
# Rows: judge models + aggregate row, Cols: aspects
# One image per persona, one heatmap per instance
# ---------------------------------------------------------------------------
short_models = [m.split("/")[-1] for m in MODELS]
row_labels   = short_models + ["Aggregate"]
n_instances  = len(instances)

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated
                       if persona in e.get("evaluations", {})}

    fig1, axes1 = plt.subplots(n_instances, 1, figsize=(6, 2.2 * n_instances))
    if n_instances == 1:
        axes1 = [axes1]

    for ax_idx, instance in enumerate(instances):
        ax    = axes1[ax_idx]
        entry = persona_entries.get(instance)

        if entry is None:
            ax.set_visible(False)
            continue

        scores = extract_scores(entry, persona)

        # Individual judge rows — same as before
        judge_matrix = np.array([
            [scores[aspect].get(model, np.nan) for aspect in ASPECTS]
            for model in MODELS
        ], dtype=float)

        # Aggregate row
        agg_row = np.array([
            entry["evaluations"][persona].get(aspect, {}).get("aggregate_score", np.nan)
            for aspect in ASPECTS
        ], dtype=float).reshape(1, -1)

        matrix = np.vstack([judge_matrix, agg_row])

        # Draw dividing line between judges and aggregate
        # by using a masked annotation style: bold for aggregate row
        sns.heatmap(
            matrix,
            ax=ax,
            annot=True,
            fmt=".1f",
            vmin=1, vmax=5,
            cmap="RdYlGn",
            xticklabels=[a.capitalize() for a in ASPECTS],
            yticklabels=row_labels,
            linewidths=0.5,
            linecolor="white",
            cbar=False,
        )

        # Bold the aggregate row label and draw a separator line
        yticklabels = ax.get_yticklabels()
        yticklabels[-1].set_fontweight("bold")
        ax.set_yticklabels(yticklabels)

        # Horizontal separator above aggregate row
        ax.axhline(y=len(MODELS), color="black", linewidth=1.5)

        ax.set_title(f"Instance {instance}", fontsize=11,
                     fontweight="bold", pad=8)
        ax.set_ylabel("")
        ax.set_xlabel("Aspect")

    fig1.suptitle(
        f"Per-Instance Evaluation Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig1.tight_layout()
    fig1.subplots_adjust(top=1)

    filename = f"visualisations/evaluation/evaluation_heatmaps_{persona}.svg"
    fig1.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig1)
# Out:
# Saved visualisations/evaluation/evaluation_heatmaps_bank_client.svg
# Saved visualisations/evaluation/evaluation_heatmaps_bank_officer.svg
# Saved visualisations/evaluation/evaluation_heatmaps_expert_judge.svg

# %% [markdown]
# ####    Plot 1b: Aggregate heatmap

# %%
# ---------------------------------------------------------------------------
# PLOT 1b — Heatmap: instances (rows) x aspects (cols)
# Value: aggregate_score averaged across personas
# Good for spotting outlier instances at a glance
# ---------------------------------------------------------------------------

# Build: instance -> aspect -> mean aggregate score across personas
instance_aspect_means = {}
for instance in instances:
    instance_aspect_means[instance] = {}
    for aspect in ASPECTS:
        scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in log_evaluated
            if e["instance_index"] == instance
            for persona in personas
            if persona in e.get("evaluations", {})
            and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        instance_aspect_means[instance][aspect] = np.mean(scores) if scores else np.nan
        
matrix = np.array([
    [instance_aspect_means[inst][aspect] for aspect in ASPECTS]
    for inst in instances
])

fig, ax = plt.subplots(figsize=(5, max(6, len(instances) * 0.4)))
sns.heatmap(
    matrix,
    ax=ax,
    annot=True,
    fmt=".1f",
    vmin=1, vmax=5,
    cmap="RdYlGn",
    xticklabels=[a.capitalize() for a in ASPECTS],
    yticklabels=[f"#{inst}" for inst in instances],
    linewidths=0.4,
    cbar_kws={"label": "Aggregate score"},
)
ax.set_title("Aggregate Score Heatmap", fontweight="bold")
ax.set_xlabel("Aspect")
ax.set_ylabel("Instance")

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_heatmap.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_heatmap.svg")
plt.close(fig)
# Out:
# Saved aggregate_heatmap.svg

# %% [markdown]
# ### Plot 2: Average scores (over all instances) per Judge and Persona

# %%
rows = []
for e in log_evaluated:
    instance = e["instance_index"]
    for persona, aspects in e["evaluations"].items():
        for aspect, models_data in aspects.items():
            for model in MODELS:
                data = models_data.get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                rows.append({
                    "instance": instance,
                    "persona": persona.replace("_", " ").title(),
                    "aspect": aspect.capitalize(),
                    "model": model.split("/")[-1],
                    "score": score,
                })

df_long = pd.DataFrame(rows).dropna(subset=["score"])

# %% [markdown]
# strip plot

# %%
fig, axes = plt.subplots(1, len(ASPECTS), figsize=(5 * len(ASPECTS), 5), sharey=True)

for i, (ax, aspect) in enumerate(zip(axes, ASPECTS)):
    data = df_long[df_long["aspect"] == aspect.capitalize()]
    sns.stripplot(
        data=data, x="persona", y="score", hue="model",
        dodge=True, jitter=0.15, ax=ax, alpha=0.5, size=6,
    )
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("Score (1-5)" if i == 0 else "")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.tick_params(axis="x", rotation=20)

    if aspect.lower() != "plausibility":
        ax.legend_.remove()
    else:
        ax.legend(title="Judge", fontsize=7, title_fontsize=8, loc="lower right")

fig.suptitle("Score Distribution per Persona & Judge", fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/strip_all_judges.svg", dpi=150, bbox_inches="tight")
plt.close(fig)

# %% [markdown]
# bar chart

# %%
cmap_models = matplotlib.colormaps.get_cmap("tab10")
colors_personas = [cmap_models(i / len(personas)) for i in range(len(personas))]

n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
bar_fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

for model in MODELS:
    short_model = model.split("/")[-1]

    fig_bar, ax_bar = plt.subplots(figsize=(bar_fig_width, 5))

    persona_aspect_means = {}
    for persona in personas:
        persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
        means = {}
        for aspect in ASPECTS:
            scores = [
                e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score")
                for e in persona_entries
                if isinstance(e["evaluations"][persona].get(aspect, {}).get(model, {}), dict)
                and e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score") is not None
            ]
            means[aspect] = np.mean(scores) if scores else 0
        persona_aspect_means[persona] = means

    x = np.arange(len(ASPECTS))

    for i, (persona, means) in enumerate(persona_aspect_means.items()):
        values = [means[a] for a in ASPECTS]
        offset = (i - n_personas / 2 + 0.5) * width
        bars = ax_bar.bar(
            x + offset, values, width,
            label=persona.replace("_", " ").title(),
            color=colors_personas[i], alpha=0.85
        )
        for bar, val in zip(bars, values):
            ax_bar.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.2f}", ha="center", va="bottom", fontsize=9
            )

    ax_bar.set_xticks(x)
    ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
    ax_bar.set_ylim(0.5, 5.5)
    ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
    ax_bar.set_ylabel("Average score over all instances")
    ax_bar.set_title(f"Average Scores per Aspect & Persona — {short_model}", fontweight="bold")
    ax_bar.legend()
    ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

    fig_bar.tight_layout()
    filename_bar = f"visualisations/evaluation/evaluation_summary_bar_{short_model}.svg"
    fig_bar.savefig(filename_bar, dpi=150, bbox_inches="tight")
    print(f"Saved {filename_bar}")
    plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_summary_bar_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_summary_bar_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_summary_bar_grok-4.20.svg

# %% [markdown]
# #### Plot 2b: Average scores (over all instances) of aggregated scores per Persona

# %% [markdown]
# The aggregate score is the majority-voted score across all judge models for a given aspect and instance — so if 3 out of 5 models give a score of 2, the aggregate score is 2. The averaged aggregate score in the bar chart then takes these per-instance aggregate scores and averages them across all 20 instances to give a single summary score per aspect per persona.

# %%
n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

cmap   = matplotlib.colormaps.get_cmap("tab10")
colors = [cmap(i / len(personas)) for i in range(len(personas))]

persona_aspect_means = {}
for persona in personas:
    persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
    means = {}
    for aspect in ASPECTS:
        agg_scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in persona_entries
            if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        means[aspect] = np.mean(agg_scores) if agg_scores else 0
    persona_aspect_means[persona] = means

x = np.arange(len(ASPECTS))

fig_bar, ax_bar = plt.subplots(figsize=(fig_width, 5))

for i, (persona, means) in enumerate(persona_aspect_means.items()):
    values = [means[a] for a in ASPECTS]
    offset = (i - n_personas / 2 + 0.5) * width
    bars = ax_bar.bar(x + offset, values, width,
                      label=persona.replace("_", " ").title(),
                      color=colors[i], alpha=0.85)
    for bar, val in zip(bars, values):
        ax_bar.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                    f"{val:.2f}", ha="center", va="bottom", fontsize=8)

ax_bar.set_xticks(x)
ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
ax_bar.set_ylim(0.5, 5.5)
ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
ax_bar.set_ylabel("Average score over all instances")
ax_bar.set_title("Average Aggregate Scores per Aspect & Persona", fontweight="bold")
ax_bar.legend()
ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig_bar.tight_layout()
fig_bar.savefig("visualisations/evaluation/evaluation_summary_bar.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_summary_bar.svg")
plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar.svg

# %% [markdown]
# ### Plot 3: Average aggregate score per aspect

# %%
# ---------------------------------------------------------------------------
# PLOT 3 — Single bar chart: average aggregate score per aspect
# Averaged across all instances AND all personas — the headline result
# ---------------------------------------------------------------------------
aspect_means = {}
aspect_sems  = {}

for aspect in ASPECTS:
    scores = [
        e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
        for e in log_evaluated
        for persona in personas
        if persona in e.get("evaluations", {})
        and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
    ]
    aspect_means[aspect] = np.mean(scores)
    aspect_sems[aspect]  = np.std(scores, ddof=1) / np.sqrt(len(scores))

colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
fig, ax = plt.subplots(figsize=(5, 5))

x = np.arange(len(ASPECTS))
bars = ax.bar(
    x,
    [aspect_means[a] for a in ASPECTS],
    yerr=[aspect_sems[a] for a in ASPECTS],
    color=colors_aspects,
    alpha=0.85,
    capsize=5,
    width=0.5,
)
for bar, aspect in zip(bars, ASPECTS):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + aspect_sems[aspect] + 0.08,
        f"{aspect_means[aspect]:.2f}",
        ha="center", va="bottom", fontsize=11, fontweight="bold"
    )

ax.set_xticks(x)
ax.set_xticklabels([a.capitalize() for a in ASPECTS], fontsize=12)
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Average aggregate score (1–5)", fontsize=11)
ax.set_title("Average Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_headline.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_headline.svg")
plt.close(fig)
# Out:
# Saved aggregate_headline.svg

# %% [markdown]
# ### Plot 4: Per persona and instance comparison between llm judges

# %%
short_models = [m.split("/")[-1] for m in MODELS]
bar_width    = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, model in enumerate(MODELS):
            short_model = short_models[k]
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(MODELS) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_model,
                color=colors[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors[k], label=short_models[k])
        for k in range(len(MODELS))
    ]
    fig.legend(handles=handles, title="Judge Model", fontsize=8,
               loc="lower center", ncol=len(MODELS),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-LLM Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_llm_scores_{persona}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_llm_scores_bank_client.svg
# Saved visualisations/evaluation/evaluation_llm_scores_bank_officer.svg
# Saved visualisations/evaluation/evaluation_llm_scores_expert_judge.svg

# %% [markdown]
# ### Plot 5: Per llm judge and instance comparison between personas

# %%
short_personas = [p.replace("_", " ").title() for p in personas]
bar_width      = 0.15
colors_p       = ["#4C72B0", "#DD8452", "#55A868"]

for model in MODELS:
    short_model = model.split("/")[-1]

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, persona in enumerate(personas):
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(personas) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_personas[k],
                color=colors_p[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors_p[k], label=short_personas[k])
        for k in range(len(personas))
    ]
    fig.legend(handles=handles, title="Persona", fontsize=8,
               loc="lower center", ncol=len(personas),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-Persona Scores — {short_model}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_persona_scores_{short_model}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_persona_scores_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_persona_scores_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_persona_scores_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_persona_scores_grok-4.20.svg

# %% [markdown]
# ####    Plot 5b: Aggregate scores per persona

# %%
# ---------------------------------------------------------------------------
# PLOT 5b — Aggregate scores per instance, coloured by persona
# 3 subplots (one per aspect), one figure total
# Replaces the per-persona loop with a single comparable figure
# ---------------------------------------------------------------------------
colors_p  = ["#4C72B0", "#DD8452", "#55A868"]
bar_width = 0.25

fig, axes = plt.subplots(len(ASPECTS), 1,
                         figsize=(max(14, len(instances) * 0.8),
                                  5 * len(ASPECTS)),
                         sharey=True)

if len(ASPECTS) == 1:
    axes = [axes]

for ax, aspect in zip(axes, ASPECTS):
    x_positions = np.arange(len(instances))

    for k, persona in enumerate(personas):
        persona_entries = {e["instance_index"]: e for e in log_evaluated
                           if persona in e.get("evaluations", {})}
        scores = []
        for instance in instances:
            entry = persona_entries.get(instance)
            if entry:
                val = entry["evaluations"][persona].get(
                    aspect, {}).get("aggregate_score")
                scores.append(val if val is not None else 0)
            else:
                scores.append(0)

        offset = (k - len(personas) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=persona.replace("_", " ").title(),
            color=colors_p[k % len(colors_p)],
            alpha=0.85,
        )
        for bar, score in zip(bars, scores):
            if score > 0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.05,
                    f"{score:.1f}",
                    ha="center", va="bottom", fontsize=7
                )

    ax.set_xticks(x_positions)
    ax.set_xticklabels([f"#{inst}" for inst in instances],
                       fontsize=9, rotation=45, ha="right")
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("Instance")
    ax.set_ylabel("Aggregate score (1–5)")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

handles = [
    mpatches.Patch(color=colors_p[k % len(colors_p)],
                   label=personas[k].replace("_", " ").title())
    for k in range(len(personas))
]
fig.legend(handles=handles, title="Persona", fontsize=8,
           loc="lower center", ncol=len(personas),
           bbox_to_anchor=(0.5, -0.05))

fig.suptitle(
    "Aggregate Scores per Instance & Persona",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_persona_per_instance.svg",
            dpi=150, bbox_inches="tight")
print("Saved aggregate_persona_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_persona_per_instance.svg

# %% [markdown]
# ### Plot 6: All metrics averaged per Persona, Judge, Instance

# %%
n_cols = 4
n_rows = math.ceil(len(instances) / n_cols)
short_models = [m.split("/")[-1] for m in MODELS]
bar_width = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6 * n_cols, 5 * n_rows), sharey=True)
axes_flat  = axes.flatten()

for ax in axes_flat[len(instances):]:
    ax.set_visible(False)

for ax, instance in zip(axes_flat, instances):
    x_positions = np.arange(len(personas))

    for k, model in enumerate(MODELS):
        short_model = short_models[k]
        scores = []

        for persona in personas:
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            entry = persona_entries.get(instance)
            if entry:
                aspect_scores = []
                for aspect in ASPECTS:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    if score is not None:
                        aspect_scores.append(score)
                scores.append(np.mean(aspect_scores) if aspect_scores else 0)
            else:
                scores.append(0)

        offset = (k - len(MODELS) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=short_model,
            color=colors[k],
            alpha=0.85,
        )

        for bar, score in zip(bars, scores):
            if score > 0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.05,
                    f"{score:.1f}",
                    ha="center", va="bottom", fontsize=6
                )

    ax.set_xticks(x_positions)
    ax.set_xticklabels(
        [p.replace("_", " ").title() for p in personas],
        fontsize=8
    )
    ax.set_title(f"Instance #{instance}", fontweight="bold", fontsize=10)
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

for ax in axes_flat[::n_cols]:
    ax.set_ylabel("Avg. score across all aspects")

handles = [
    mpatches.Patch(color=colors[k], label=short_models[k])
    for k in range(len(MODELS))
]
fig.legend(handles=handles, title="Judge Model", fontsize=8,
            loc="lower center", ncol=len(MODELS),
            bbox_to_anchor=(0.5, -0.02))

fig.suptitle(
    "Average score across all aspects per Persona, Judge and Instance\n"
    "(faithfulness, helpfulness and plausibility averaged)",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/evaluation_faceted.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_faceted.svg")
plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_faceted.svg

# %% [markdown]
# ### Plot 7: Score distribution per judge across all aspects and personas

# %%
short_models = [m.split("/")[-1] for m in MODELS]

fig, axes = plt.subplots(1, len(MODELS), figsize=(4 * len(MODELS), 4), sharey=True)

for ax, model in zip(axes, MODELS):
    short_model = model.split("/")[-1]
    scores = []

    for e in log_evaluated:
        for persona in personas:
            if persona not in e.get("evaluations", {}):
                continue
            for aspect in ASPECTS:
                data = e["evaluations"][persona].get(aspect, {}).get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                if score is not None:
                    scores.append(score)

    ax.hist(scores, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
            color="#4C72B0", edgecolor="white", alpha=0.85)
    ax.set_title(short_model, fontweight="bold", fontsize=9)
    ax.set_xlabel("Score")
    ax.set_ylabel("Count" if ax == axes[0] else "")
    ax.set_xticks([1, 2, 3, 4, 5])
    ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig.suptitle("Score Distribution per Judge (all aspects & personas)",
             fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/score_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/score_distribution.svg")
# Out:
# Saved visualisations/evaluation/score_distribution.svg

# %% [markdown]
# ####    Plot 7b: Aggregate score distribution

# %%
# ---------------------------------------------------------------------------
# PLOT 7b — Distribution of aggregate scores across all instances,
# aspects and personas — shows overall calibration of the pipeline
# ---------------------------------------------------------------------------
all_agg_scores = [
    e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
    for e in log_evaluated
    for persona in personas
    if persona in e.get("evaluations", {})
    for aspect in ASPECTS
    if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
]

fig, ax = plt.subplots(figsize=(5, 4))
ax.hist(
    all_agg_scores,
    bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
    color="#4C72B0", edgecolor="white", alpha=0.85
)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xlabel("Aggregate score", fontsize=11)
ax.set_ylabel("Count", fontsize=11)
ax.set_title("Aggregate Score Distribution", fontweight="bold")
ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

mean_agg = np.mean(all_agg_scores)
ax.axvline(x=mean_agg, color="#C44E52", linestyle="-", linewidth=1.5, label=f"Mean = {mean_agg:.2f}")
ax.legend(fontsize=9)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_distribution.svg")
plt.close(fig)
# Out:
# Saved aggregate_distribution.svg

# %% [markdown]
# ### Plot 8: Per instance aggregate scores per aspect

# %%
# ---------------------------------------------------------------------------
# PLOT 8 — Per-instance aggregate scores per aspect
# Aggregate_score averaged across personas, shown per instance
# Primary result figure: shows narrative quality across the 20 instances
# ---------------------------------------------------------------------------
colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
bar_width = 0.25

x_positions = np.arange(len(instances))
fig, ax = plt.subplots(figsize=(max(12, len(instances) * 0.7), 5))

for k, (aspect, color) in enumerate(zip(ASPECTS, colors_aspects)):
    values = [instance_aspect_means[inst][aspect] for inst in instances]
    offset = (k - len(ASPECTS) / 2 + 0.5) * bar_width
    bars = ax.bar(
        x_positions + offset, values,
        width=bar_width, label=aspect.capitalize(),
        color=color, alpha=0.85
    )
    for bar, val in zip(bars, values):
        if not np.isnan(val):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.1f}", ha="center", va="bottom", fontsize=7
            )

ax.set_xticks(x_positions)
ax.set_xticklabels([f"#{inst}" for inst in instances], fontsize=9, rotation=45, ha="right")
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Aggregate score (averaged across personas)", fontsize=10)
ax.set_xlabel("Instance", fontsize=10)
ax.set_title("Per-Instance Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.legend(title="Aspect", fontsize=9, loc="lower left")
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_per_instance.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_per_instance.svg
