# %% [markdown]
# # 1. Imports

# %%
import pickle
import glob
import re
import os
import json
import textwrap
import math
from types import SimpleNamespace
from collections import defaultdict
from itertools import cycle

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns

from token_shap_story import TokenSHAPstory
import config

# %%
# --- Load Shapley values from pkl files ---
pkl_files = sorted(glob.glob("tokenshap_results/tokenshap_results_instance_*.pkl"))

dfs = {}  # {instance_id (int): DataFrame with columns [token, shapley_value, position]}

for fname in pkl_files:
    with open(fname, "rb") as f:
        tokenshap_results = pickle.load(f)

    token_shap = SimpleNamespace(**tokenshap_results)

    shap_df = pd.DataFrame([
        {"token": k.rsplit("_", 1)[0], "shapley_value": round(float(v), 4)}
        for k, v in token_shap.shapley_values.items()
    ]).assign(position=lambda df: range(len(df))) \
      .sort_values("shapley_value", ascending=False) \
      .reset_index(drop=True)

    instance_id = int(re.search(r"instance_(\d+)", fname).group(1))
    dfs[instance_id] = shap_df

# --- Load log (narratives + evaluations) ---
with open(config.LOG_JSON, "r") as f:
    log = json.load(f)

# Convenience lookup: {instance_id (int): log entry}
log_by_instance = {e["instance_index"]: e for e in log}

# Filter to evaluated entries only
log_evaluated = [e for e in log if "evaluations" in e]

instances = sorted(set(e["instance_index"] for e in log_evaluated))
personas  = sorted(set(
    p for e in log_evaluated
    for p in e["evaluations"].keys()
))

ASPECTS = config.JUDGE_ASPECTS
MODELS  = config.JUDGE_MODELS

# %% [markdown]
# # 2. Print all Shapley values

# %%
for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    print(df[["token", "shapley_value"]].to_string(index=False))
# Out:
# === instance_0 ===
#              token  shapley_value
#             228.69         1.0000
#               36.6         0.8495
#               67.0         0.7698
#                  1         0.6184
#               Male         0.5976
#           formerly         0.5743
#             smoked         0.4268
#              Urban         0.4088
#      hypertension:         0.3098
#               age:         0.2305
#                Yes         0.2179
# avg_glucose_level:         0.1922
#     heart_disease:         0.1809
#    smoking_status:         0.1574
#            Private         0.1491
#           profile:         0.0562
#               bmi:         0.0122
#            gender:        -0.2258
#    Residence_type:        -0.2299
#      ever_married:        -0.2354
#                  0        -0.2891
#         work_type:        -0.3025
#            Patient        -0.3798
#
# === instance_4 ===
#              token  shapley_value
#               79.0         1.0000
#             174.12         0.6135
#                  1         0.5759
#      hypertension:         0.3629
#     heart_disease:         0.3399
#                Yes         0.3348
#              Rural         0.2340
# avg_glucose_level:         0.2106
#               age:         0.1989
#               24.0         0.1951
#             smoked         0.1676
#             Female         0.1485
#      Self-employed         0.1428
#         work_type:         0.1394
#              never         0.0638
#    Residence_type:         0.0119
#           profile:        -0.0081
#    smoking_status:        -0.0169
#            Patient        -0.0712
#                  0        -0.1040
#            gender:        -0.1054
#      ever_married:        -0.1509
#               bmi:        -0.1548
#
# === instance_17 ===
#              token  shapley_value
#             smokes         1.0000
#               75.0         0.9304
#                  1         0.7831
#             221.29         0.7654
#               25.8         0.5604
#               Male         0.5209
#     heart_disease:         0.3759
#              Urban         0.2831
#      hypertension:         0.2712
#            Private         0.2686
#                Yes         0.2122
# avg_glucose_level:         0.1597
#               age:         0.1249
#    smoking_status:         0.0473
#                  0        -0.0094
#    Residence_type:        -0.0102
#         work_type:        -0.0368
#           profile:        -0.1754
#      ever_married:        -0.1981
#               bmi:        -0.2473
#            Patient        -0.3841
#            gender:        -0.4026
#
# === instance_30 ===
#              token  shapley_value
#             smokes         1.0000
#               44.2         0.9122
#                  1         0.6902
#               57.0         0.6772
#      hypertension:         0.6428
#             212.08         0.6360
#              Urban         0.5704
#                Yes         0.3952
# avg_glucose_level:         0.3932
#            Private         0.2997
#               Male         0.2962
#         work_type:         0.2203
#     heart_disease:         0.0706
#               age:         0.0664
#                  0         0.0387
#    smoking_status:        -0.0117
#               bmi:        -0.0143
#           profile:        -0.0684
#    Residence_type:        -0.1474
#      ever_married:        -0.1807
#            Patient        -0.3182
#            gender:        -0.5641
#
# === instance_49 ===
#              token  shapley_value
#             smokes         1.0000
#               39.2         0.7646
#      hypertension:         0.6946
#                  1         0.5445
#               bmi:         0.4229
#    smoking_status:         0.3911
#              Rural         0.2151
#            Private         0.1586
#              58.09         0.1128
#     heart_disease:         0.1111
#                Yes         0.0893
#           profile:        -0.0526
#               39.0        -0.0548
#               age:        -0.1319
#         work_type:        -0.2174
#             Female        -0.2362
#                  0        -0.2363
#    Residence_type:        -0.2435
#            gender:        -0.2507
#            Patient        -0.2641
#      ever_married:        -0.3328
# avg_glucose_level:        -0.5035
#
# === instance_52 ===
#              token  shapley_value
#               79.0         1.0000
#                  1         0.4767
#             127.29         0.3191
#               27.7         0.2842
#                Yes         0.2403
#             Female         0.2156
#     heart_disease:         0.1520
#              Rural         0.1423
# avg_glucose_level:         0.1422
#         work_type:         0.1012
#              never         0.0934
#             smoked         0.0887
#               age:         0.0637
#           profile:         0.0624
#            Private         0.0478
#      ever_married:        -0.0053
#    smoking_status:        -0.0160
#      hypertension:        -0.0246
#    Residence_type:        -0.0375
#               bmi:        -0.0519
#            Patient        -0.0990
#                  0        -0.1248
#            gender:        -0.2816
#
# === instance_74 ===
#              token  shapley_value
#              never         1.0000
#             Female         0.7026
#                  0         0.6663
#                  0         0.6385
#               26.4         0.4783
#            Private         0.3407
#    smoking_status:         0.3069
#      hypertension:         0.2728
#              Rural         0.2448
# avg_glucose_level:         0.2037
#              96.59         0.1907
#               52.0         0.1361
#      ever_married:         0.1007
#    Residence_type:         0.0551
#         work_type:         0.0514
#               bmi:         0.0432
#               age:         0.0230
#                Yes        -0.0360
#           profile:        -0.0786
#             smoked        -0.1286
#            Patient        -0.2345
#     heart_disease:        -0.2435
#            gender:        -0.2899
#
# === instance_86 ===
#              token  shapley_value
#             smokes         1.0000
#               61.0         0.8435
#               27.3         0.7092
#             111.81         0.5690
#                  1         0.5182
#               Male         0.2250
#            Private         0.2061
#     heart_disease:         0.2041
#              Rural         0.1924
#                Yes         0.1878
# avg_glucose_level:         0.1793
#    smoking_status:         0.1471
#      hypertension:         0.1052
#           profile:         0.0026
#               bmi:        -0.0002
#               age:        -0.0143
#    Residence_type:        -0.0804
#         work_type:        -0.1091
#            gender:        -0.1944
#      ever_married:        -0.2205
#            Patient        -0.2885
#                  0        -0.3154
#
# === instance_141 ===
#              token  shapley_value
#               23.8         1.0000
#                  0         0.9125
#             Female         0.7391
#                  0         0.7169
#      hypertension:         0.5125
#              Rural         0.2806
#            Private         0.2210
#               bmi:         0.2195
#    Residence_type:         0.0774
#               age:         0.0263
#             116.44         0.0260
# avg_glucose_level:         0.0071
#      ever_married:        -0.0333
#           profile:        -0.0464
#         work_type:        -0.0927
#    smoking_status:        -0.1758
#     heart_disease:        -0.1800
#                Yes        -0.2149
#            gender:        -0.3211
#            Patient        -0.3777
#               59.0        -0.4067
#             smokes        -0.4955
#
# === instance_196 ===
#              token  shapley_value
#               70.0         1.0000
#               45.5         0.8886
#             242.52         0.7959
#           formerly         0.7540
#                  1         0.5944
#               Male         0.5034
#              Rural         0.4660
#            Private         0.3910
#                Yes         0.3813
#    smoking_status:         0.3455
#      hypertension:         0.3296
#             smoked         0.2525
#               bmi:         0.2209
# avg_glucose_level:         0.1815
#     heart_disease:         0.1366
#               age:         0.1276
#                  0        -0.1066
#    Residence_type:        -0.1236
#         work_type:        -0.1258
#      ever_married:        -0.1489
#           profile:        -0.1744
#            Patient        -0.3274
#            gender:        -0.4087
#
# === instance_255 ===
#              token  shapley_value
#               17.7         1.0000
#             Female         0.9778
#                  0         0.9492
#              77.59         0.9043
#                  0         0.8748
#      hypertension:         0.6323
#               bmi:         0.5947
# avg_glucose_level:         0.5749
#              Urban         0.5010
#            Private         0.4141
#           formerly         0.3511
#               52.0         0.2907
#      ever_married:         0.0858
#         work_type:         0.0829
#    smoking_status:         0.0239
#                Yes        -0.0138
#    Residence_type:        -0.0195
#               age:        -0.1223
#     heart_disease:        -0.1258
#             smoked        -0.2521
#            gender:        -0.2792
#            Patient        -0.4026
#           profile:        -0.5211
#
# === instance_302 ===
#              token  shapley_value
#              never         1.0000
#                  0         0.6811
#                  0         0.6284
#               25.1         0.5747
#      hypertension:         0.5364
#               44.0         0.5177
#              81.84         0.3817
#              Rural         0.2441
#               Male         0.2145
# avg_glucose_level:         0.1801
#            Private         0.1695
#                Yes         0.1233
#               bmi:         0.1121
#    smoking_status:         0.0706
#             smoked        -0.0454
#      ever_married:        -0.0461
#               age:        -0.0756
#         work_type:        -0.0845
#            Patient        -0.1456
#    Residence_type:        -0.1514
#            gender:        -0.1837
#           profile:        -0.2736
#     heart_disease:        -0.4412
#
# === instance_386 ===
#              token  shapley_value
#              251.6         1.0000
#               70.0         0.9876
#                  1         0.6902
# avg_glucose_level:         0.5533
#               27.1         0.5003
#                Yes         0.4809
#               Male         0.4582
#      hypertension:         0.3597
#      Self-employed         0.2764
#     heart_disease:         0.2363
#              Urban         0.2320
#             smoked         0.1694
#    smoking_status:         0.1487
#           profile:         0.1422
#               age:         0.1375
#    Residence_type:         0.0479
#         work_type:         0.0132
#               bmi:        -0.0142
#              never        -0.0263
#            Patient        -0.1879
#                  0        -0.2234
#      ever_married:        -0.2879
#            gender:        -0.3583
#
# === instance_500 ===
#              token  shapley_value
#                  0         1.0000
#                  0         0.9221
#             Female         0.8702
#              77.49         0.8502
# avg_glucose_level:         0.5859
#           formerly         0.5191
#      hypertension:         0.3541
#              Urban         0.3243
#            Private         0.3037
#               56.0         0.1590
#    smoking_status:         0.1543
#               36.0         0.1423
#    Residence_type:         0.0352
#      ever_married:         0.0004
#                Yes         0.0004
#           profile:        -0.0029
#         work_type:        -0.0064
#             smoked        -0.1959
#               age:        -0.2276
#            gender:        -0.2746
#            Patient        -0.3616
#     heart_disease:        -0.4616
#               bmi:        -0.5701
#
# === instance_600 ===
#              token  shapley_value
#               24.0         1.0000
#             Female         0.6313
#              never         0.5076
#               23.4         0.4186
#                  0         0.3706
#                 No         0.2883
#              Rural         0.2428
#                  0         0.2368
#    smoking_status:         0.1461
# avg_glucose_level:         0.1268
#      hypertension:         0.1072
#             115.03         0.1071
#               age:         0.0735
#      Self-employed         0.0200
#             smoked         0.0092
#         work_type:        -0.0022
#      ever_married:        -0.0133
#    Residence_type:        -0.0282
#               bmi:        -0.0759
#           profile:        -0.1140
#     heart_disease:        -0.1752
#            Patient        -0.1949
#            gender:        -0.3265
#
# === instance_825 ===
#              token  shapley_value
#                  0         1.0000
#                  0         0.9144
#              73.75         0.6822
#               27.3         0.5767
#      hypertension:         0.4472
#              Rural         0.3539
#               Male         0.3227
# avg_glucose_level:         0.3177
#                Yes         0.2511
#         work_type:         0.2158
#    Residence_type:         0.0805
#           Govt_job         0.0260
#            gender:        -0.0208
#     heart_disease:        -0.1666
#               bmi:        -0.3261
#           profile:        -0.3337
#      ever_married:        -0.3809
#    smoking_status:        -0.4332
#               age:        -0.4791
#               59.0        -0.5213
#            Patient        -0.7342
#             smokes        -0.9146
#
# === instance_924 ===
#              token  shapley_value
#              never         1.0000
#                  0         0.7569
#                  0         0.7537
#             Female         0.6346
#               24.8         0.5309
#      hypertension:         0.4251
#            Private         0.3083
#              87.11         0.2588
# avg_glucose_level:         0.2187
#    smoking_status:         0.1629
#               bmi:         0.1506
#                Yes         0.1392
#              Urban        -0.0053
#            gender:        -0.0080
#      ever_married:        -0.0104
#             smoked        -0.0593
#         work_type:        -0.1069
#           profile:        -0.1588
#     heart_disease:        -0.1784
#               age:        -0.1906
#    Residence_type:        -0.1939
#            Patient        -0.2391
#               74.0        -0.7911
#
# === instance_1295 ===
#              token  shapley_value
#                  0         1.0000
#              never         0.9422
#                  0         0.6889
#      hypertension:         0.5746
#    smoking_status:         0.3375
#              Rural         0.2854
#    Residence_type:         0.2139
#             smoked         0.2027
#            Private         0.1329
#                Yes         0.1227
#      ever_married:         0.1122
#               age:         0.0812
#               32.8         0.0444
# avg_glucose_level:         0.0424
#               Male         0.0368
#             101.34        -0.0465
#            gender:        -0.0580
#     heart_disease:        -0.0583
#               bmi:        -0.0646
#         work_type:        -0.1407
#            Patient        -0.1582
#           profile:        -0.1770
#               60.0        -0.2286
#
# === instance_1322 ===
#              token  shapley_value
#              206.4         1.0000
#               54.8         0.9460
#               55.0         0.9316
#                  1         0.8355
#      hypertension:         0.6137
#              Urban         0.4261
#                Yes         0.3859
#            Private         0.3770
#     heart_disease:         0.3367
#             Female         0.2992
# avg_glucose_level:         0.2853
#    Residence_type:         0.2199
#    smoking_status:         0.1458
#               bmi:         0.1231
#             smoked         0.1003
#              never         0.0155
#           profile:        -0.0340
#               age:        -0.0371
#         work_type:        -0.1700
#      ever_married:        -0.2218
#            gender:        -0.2218
#                  0        -0.2536
#            Patient        -0.3028
#
# === instance_1362 ===
#              token  shapley_value
#                  0         1.0000
#             Female         0.9171
#                  0         0.8336
#      hypertension:         0.7690
#               26.9         0.4416
#              Rural         0.4134
#           formerly         0.3572
#                Yes         0.2867
#             103.25         0.2829
#      Self-employed         0.1831
#    smoking_status:         0.1453
# avg_glucose_level:         0.1292
#         work_type:         0.0796
#      ever_married:         0.0322
#     heart_disease:         0.0268
#             smoked        -0.0499
#            gender:        -0.0749
#    Residence_type:        -0.0969
#               bmi:        -0.0977
#               age:        -0.1077
#            Patient        -0.2940
#           profile:        -0.3027
#               72.0        -0.8097

# %% [markdown]
# for reference: {shap_table} which gets added to the narrative prompt (tokenshap_story.py) and faithfulness evaluation prompt (evaluation_prompts.py)

# %%
storyteller = TokenSHAPstory(api_key="dummy", model_name="dummy")

pkl_path = "tokenshap_results/tokenshap_results_instance_0.pkl"
with open(pkl_path, "rb") as f:
    tokenshap_results = pickle.load(f)

token_shap = SimpleNamespace(**tokenshap_results)
shap_df = storyteller.build_shap_df(token_shap)
print(shap_df.to_string(index=False))
# Out:
#              token  shap_value
#             228.69    1.000000
#               36.6    0.849545
#               67.0    0.769777
#                  1    0.618353
#               Male    0.597636
#           formerly    0.574313
#             smoked    0.426845
#              Urban    0.408752
#      hypertension:    0.309773
#               age:    0.230545
#                Yes    0.217925
# avg_glucose_level:    0.192160
#     heart_disease:    0.180944
#    smoking_status:    0.157443
#            Private    0.149070
#           profile:    0.056171
#               bmi:    0.012190
#            gender:   -0.225842
#    Residence_type:   -0.229883
#      ever_married:   -0.235381
#                  0   -0.289090
#         work_type:   -0.302474
#            Patient   -0.379815

# %% [markdown]
# ## 2b. Print all evaluations

# %%
for entry in log_evaluated:
    instance_id = entry["instance_index"]
    print(f"\n=== instance_{instance_id} ===")
    rows = []
    for persona, aspects in entry["evaluations"].items():
        for aspect, data in aspects.items():
            agg = data.get("aggregate_score")
            rows.append({"persona": persona, "aspect": aspect, "aggregate_score": agg})
    df_agg = pd.DataFrame(rows)
    print(df_agg.to_string(index=False))
# Out:
# === instance_0 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              4.0
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.0
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.0
#  doctor_elaborate  helpfulness              5.0
#  doctor_elaborate plausibility              4.0
#
# === instance_1295 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              2.0
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              4.0
#           patient faithfulness              2.0
#           patient  helpfulness              4.5
#           patient plausibility              4.0
#            doctor faithfulness              2.0
#            doctor  helpfulness              4.5
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.0
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              2.5
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              4.0
#
# === instance_1322 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              5.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              5.0
#           patient  helpfulness              4.5
#           patient plausibility              4.0
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              5.0
# patient_elaborate  helpfulness              5.0
# patient_elaborate plausibility              4.5
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              4.5
#
# === instance_1362 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.0
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.0
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              3.0
#
# === instance_141 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              5.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              4.0
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              5.0
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              4.5
#  doctor_elaborate faithfulness              5.0
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              4.0
#
# === instance_17 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              5.0
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              5.0
# patient_elaborate plausibility              5.0
#  doctor_elaborate faithfulness              5.0
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              4.0
#
# === instance_196 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              4.0
#           patient faithfulness              5.0
#           patient  helpfulness              5.0
#           patient plausibility              4.0
#            doctor faithfulness              4.5
#            doctor  helpfulness              5.0
#            doctor plausibility              3.5
# patient_elaborate faithfulness              5.0
# patient_elaborate  helpfulness              3.5
# patient_elaborate plausibility              3.5
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              3.0
#
# === instance_255 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              3.5
#           patient faithfulness              4.5
#           patient  helpfulness              3.0
#           patient plausibility              3.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              3.0
#            doctor plausibility              2.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              3.5
# patient_elaborate plausibility              3.5
#  doctor_elaborate faithfulness              5.0
#  doctor_elaborate  helpfulness              2.0
#  doctor_elaborate plausibility              2.0
#
# === instance_30 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              4.5
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              5.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              4.0
#
# === instance_302 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              3.5
#           patient faithfulness              4.5
#           patient  helpfulness              4.0
#           patient plausibility              3.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              3.0
#            doctor plausibility              3.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              3.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              2.0
#  doctor_elaborate plausibility              2.0
#
# === instance_386 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              5.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              4.5
#  doctor_elaborate plausibility              4.5
#
# === instance_4 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness             3.25
#      expert_judge  helpfulness             4.50
#      expert_judge plausibility             4.50
#           patient faithfulness             4.00
#           patient  helpfulness             4.50
#           patient plausibility             4.50
#            doctor faithfulness             5.00
#            doctor  helpfulness             4.50
#            doctor plausibility             4.50
# patient_elaborate faithfulness             4.50
# patient_elaborate  helpfulness             5.00
# patient_elaborate plausibility             4.50
#  doctor_elaborate faithfulness             5.00
#  doctor_elaborate  helpfulness             4.00
#  doctor_elaborate plausibility             4.00
#
# === instance_49 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              5.0
#           patient faithfulness              4.0
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              4.5
#  doctor_elaborate plausibility              4.5
#
# === instance_500 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              2.0
#      expert_judge  helpfulness              3.5
#      expert_judge plausibility              3.5
#           patient faithfulness              2.0
#           patient  helpfulness              4.0
#           patient plausibility              3.5
#            doctor faithfulness              2.0
#            doctor  helpfulness              4.0
#            doctor plausibility              3.5
# patient_elaborate faithfulness              2.0
# patient_elaborate  helpfulness              3.5
# patient_elaborate plausibility              3.0
#  doctor_elaborate faithfulness              2.0
#  doctor_elaborate  helpfulness              2.0
#  doctor_elaborate plausibility              2.0
#
# === instance_52 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              5.0
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              5.0
# patient_elaborate plausibility              5.0
#  doctor_elaborate faithfulness              5.0
#  doctor_elaborate  helpfulness              4.0
#  doctor_elaborate plausibility              5.0
#
# === instance_600 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              5.0
#           patient faithfulness              4.5
#           patient  helpfulness              4.0
#           patient plausibility              5.0
#            doctor faithfulness              4.5
#            doctor  helpfulness              5.0
#            doctor plausibility              5.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              5.0
# patient_elaborate plausibility              3.5
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.5
#  doctor_elaborate plausibility              3.5
#
# === instance_74 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.0
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              3.0
#           patient faithfulness              4.5
#           patient  helpfulness              5.0
#           patient plausibility              4.0
#            doctor faithfulness              4.5
#            doctor  helpfulness              3.0
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              4.0
# patient_elaborate plausibility              3.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.5
#  doctor_elaborate plausibility              3.5
#
# === instance_825 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              2.5
#      expert_judge  helpfulness              4.5
#      expert_judge plausibility              4.5
#           patient faithfulness              3.0
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              2.5
#            doctor  helpfulness              4.5
#            doctor plausibility              4.5
# patient_elaborate faithfulness              2.0
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              2.0
#  doctor_elaborate  helpfulness              4.5
#  doctor_elaborate plausibility              4.0
#
# === instance_86 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              4.5
#      expert_judge  helpfulness              4.0
#      expert_judge plausibility              4.0
#           patient faithfulness              4.5
#           patient  helpfulness              4.5
#           patient plausibility              4.5
#            doctor faithfulness              4.5
#            doctor  helpfulness              5.0
#            doctor plausibility              4.0
# patient_elaborate faithfulness              4.5
# patient_elaborate  helpfulness              3.0
# patient_elaborate plausibility              4.0
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              3.0
#  doctor_elaborate plausibility              3.0
#
# === instance_924 ===
#           persona       aspect  aggregate_score
#      expert_judge faithfulness              5.0
#      expert_judge  helpfulness              5.0
#      expert_judge plausibility              4.5
#           patient faithfulness              5.0
#           patient  helpfulness              5.0
#           patient plausibility              4.5
#            doctor faithfulness              5.0
#            doctor  helpfulness              5.0
#            doctor plausibility              4.5
# patient_elaborate faithfulness              5.0
# patient_elaborate  helpfulness              4.5
# patient_elaborate plausibility              4.5
#  doctor_elaborate faithfulness              4.5
#  doctor_elaborate  helpfulness              5.0
#  doctor_elaborate plausibility              4.0

# %% [markdown]
# # 3. Print everything for specific instance

# %%
instance_id = 500

entry = log_by_instance[instance_id]
df = dfs[instance_id]

print(f"=== Instance {instance_id} ===")
print(f"\nLLM response: '{entry['baseline_response']}'")

print(f"\nAttributions (sorted by influence):")
print(df[["token", "shapley_value"]].to_string(index=False))

print(f"\nNarrative:")
print(textwrap.fill(entry["story"], width=150))

print(f"\nEvaluation scores (final score per judge):")
for persona, aspects in entry.get("evaluations", {}).items():
    print(f"\n  {'='*50}")
    print(f"  {persona.replace('_', ' ').title()}")
    print(f"  {'='*50}")
    for aspect, models in aspects.items():
        agg = models.get("aggregate_score")
        print(f"    {aspect.capitalize():<15} aggregate: {agg}")
        for model in config.JUDGE_MODELS:
            data = models.get(model, {})
            score = data.get("final_score") if isinstance(data, dict) else None
            short_model = model.split("/")[-1]
            print(f"      {short_model:<35} {score}")
# Out:
# === Instance 500 ===
#
# LLM response: 'Low'
#
# Attributions (sorted by influence):
#              token  shapley_value
#                  0         1.0000
#                  0         0.9221
#             Female         0.8702
#              77.49         0.8502
# avg_glucose_level:         0.5859
#           formerly         0.5191
#      hypertension:         0.3541
#              Urban         0.3243
#            Private         0.3037
#               56.0         0.1590
#    smoking_status:         0.1543
#               36.0         0.1423
#    Residence_type:         0.0352
#      ever_married:         0.0004
#                Yes         0.0004
#           profile:        -0.0029
#         work_type:        -0.0064
#             smoked        -0.1959
#               age:        -0.2276
#            gender:        -0.2746
#            Patient        -0.3616
#     heart_disease:        -0.4616
#               bmi:        -0.5701
#
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a digital detective weighing different clues to reach its "Low" risk verdict. The most
# powerful "green lights" for this decision were the patient’s gender being **Female** and her blood sugar sitting at a stable **77.49**, both of which
# the model strongly associated with lower immediate stroke risk. Interestingly, while things like her "Private" job or living in an "Urban" area played
# minor supporting roles, the AI’s attention was highly concentrated on specific medical markers rather than lifestyle labels.  However, the decision
# wasn’t unanimous; the model had to ignore some "red flags" that tried to pull its prediction toward a "High" risk result. The most significant
# pushback came from her **BMI of 36.0** and the **heart_disease** category, which usually signal higher danger. Surprisingly, the patient’s **age** of
# 56 and her status as someone who **formerly smoked** didn't carry as much weight as one might expect, acting as relatively neutral factors in this
# specific calculation. Ultimately, because the positive influence of her stable glucose and gender far outweighed the negative signals from her BMI,
# the AI concluded she fell into the low-risk category.  **Summary:** The model reached a "Low" risk conclusion primarily because the protective weight
# of the patient’s gender and healthy glucose levels overpowered the clinical concerns regarding her BMI and heart health.
#
# Evaluation scores (final score per judge):
#
#   ==================================================
#   Expert Judge
#   ==================================================
#     Faithfulness    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              2
#       claude-sonnet-4.6                   3
#       grok-4.20                           1
#     Helpfulness     aggregate: 3.5
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Plausibility    aggregate: 3.5
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#
#   ==================================================
#   Patient
#   ==================================================
#     Faithfulness    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              2
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Helpfulness     aggregate: 4
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 3.5
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#
#   ==================================================
#   Doctor
#   ==================================================
#     Faithfulness    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              2
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Helpfulness     aggregate: 4
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   4
#       grok-4.20                           5
#     Plausibility    aggregate: 3.5
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#
#   ==================================================
#   Patient Elaborate
#   ==================================================
#     Faithfulness    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              2
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Helpfulness     aggregate: 3.5
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              4
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#     Plausibility    aggregate: 3
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              3
#       claude-sonnet-4.6                   3
#       grok-4.20                           5
#
#   ==================================================
#   Doctor Elaborate
#   ==================================================
#     Faithfulness    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              2
#       claude-sonnet-4.6                   3
#       grok-4.20                           1
#     Helpfulness     aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              3
#       claude-sonnet-4.6                   2
#       grok-4.20                           5
#     Plausibility    aggregate: 2
#       gpt-5.4                             2
#       gemini-3.1-pro-preview              3
#       claude-sonnet-4.6                   2
#       grok-4.20                           5

# %% [markdown]
# # 4. Print narratives

# %%
for entry in log:
    print(f"=== Instance: {entry['instance_index']} ===")
    print(f"LLM response: '{entry['baseline_response']}'")
    print(f"Narrative:\n{textwrap.fill(entry['story'], width=150)}")
    print()
# Out:
# === Instance: 0 ===
# LLM response: 'High'
# Narrative:
# When the AI analyzed this patient, it acted like a medical detective weighing clues to solve a mystery, but some clues carried far more weight than
# others. The standout pieces of evidence that drove the "High" risk prediction were the numbers **228.69** (glucose) and **36.6** (BMI). These specific
# values were the most powerful "players" in the model's decision-making game, overshadowing general labels like "bmi" or "glucose level" itself. The
# model then locked onto the patient’s age of **67.0** and the presence of heart disease (indicated by the **1**), viewing these as critical red flags
# that pushed the diagnosis toward a high-risk category.  Interestingly, while the model noted the patient was **Male** and **formerly smoked**, these
# factors were secondary compared to the actual clinical measurements. On the other hand, the model saw the **0** for hypertension and the patient’s
# **private** work type as "low-risk" signals that tried to pull the prediction in the opposite direction. Ultimately, the high biological markers—the
# blood sugar and weight—teamed up with age to overwhelm those few healthy signs. The AI's final answer was a mathematical "tug-of-war" won by the most
# extreme health data points.  **Summary:** The AI prioritized specific physiological data (high glucose, BMI, and age) as the strongest drivers for a
# "High" risk prediction, while viewing descriptive categories and the absence of hypertension as minor counter-arguments.
#
# === Instance: 1295 ===
# LLM response: 'Low'
# Narrative:
# When the AI looked at this patient’s profile to predict stroke risk, it acted like a judge weighing evidence on a scale, ultimately deciding the risk
# was "Low." The most powerful "witnesses" for this decision were the two zeros appearing next to **hypertension** and **heart_disease**, which acted as
# heavy weights pulling the scale toward a safe result. The AI was particularly swayed by the phrase **"never smoked,"** treating the absence of tobacco
# use as a massive protective shield for the patient. Interestingly, even though the patient is **60 years old**, the model largely ignored his age,
# which we might expect to be a major risk factor; instead, the value "-0.22" shows that his age was actually the strongest force trying to push the
# prediction toward "High." Other details, like his **Private** job or **Rural** living situation, barely nudged the needle, acting as minor background
# noise rather than deciding factors. The AI ultimately prioritized "clean" medical markers—no high blood pressure, no heart issues, and no smoking
# history—over the natural risk that comes with getting older. Even the patient's BMI and glucose levels were treated as secondary clues compared to the
# definitive "0" on his heart health report.  **Summary:** The model predicted a "Low" risk because it focused almost entirely on the absence of
# hypertension, heart disease, and smoking, which outweighed the negative influence of the patient's age. This shows that the AI prioritizes specific
# "green flag" lifestyle markers over general demographic risks like being 60 years old.
#
# === Instance: 1322 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a digital detective looking for the most alarming "clues" to justify its "High" risk
# prediction. The most powerful evidence didn't come from labels like "gender" or "work type," but from the raw numbers themselves: the blood glucose of
# **206.4**, the BMI of **54.8**, and the age of **55.0** sat at the very top of its influence list. These specific values acted as the primary drivers,
# signaling to the model that the patient’s physical health markers were in a critical zone. Interestingly, while the label "hypertension" was
# influential, the simple number **1** (indicating she has the condition) carried even more weight in pushing the model toward a high-risk conclusion.
# Conversely, general context words like "Patient" and "gender" actually pulled the model away from its final answer, suggesting that the AI finds
# demographic labels less convincing than specific medical data. Even more surprising was that her history as someone who "never smoked" had almost zero
# impact on the decision; the model was so focused on the high glucose and BMI that the absence of smoking couldn't lower the risk score. Because the
# values for glucose and BMI were so extreme, they effectively drowned out the more neutral information about her job or marital status. In short, the
# AI’s "High" risk verdict was a direct mathematical response to a cluster of severe health metrics that it prioritized over everything else.
# **Summary:** The AI reached its "High" risk conclusion by focusing almost exclusively on specific high-value numbers—glucose level, BMI, and age—while
# largely ignoring demographic factors and the patient's non-smoking status.
#
# === Instance: 1362 ===
# LLM response: 'Low'
# Narrative:
# When a 72-year-old patient’s profile was fed into the AI, the model predicted a "Low" risk of stroke, but the reasons behind its decision reveal a
# fascinating internal tug-of-war. The most powerful drivers for the "Low" risk prediction were the two zeros next to hypertension and heart disease,
# along with the patient being female. These "pockets of health" acted like heavy anchors, pulling the model toward a safe conclusion despite the
# patient's advanced age. Interestingly, while most people assume age is the primary factor in health, the model actually treated the token "72.0" as a
# major red flag that worked against its final answer. The TokenSHAP analysis shows that "72.0" had the strongest negative influence, meaning the AI had
# to "overcome" the risk of her age to settle on a low-risk result. Other factors, like her rural lifestyle and BMI of 26.9, provided smaller nudges
# toward the "Low" result, while her history as a former smoker had surprisingly little impact on the final outcome. Essentially, the model functioned
# like a scale: the absence of chronic diseases (the zeros) and her gender outweighed the significant risk typically associated with being 72. This
# reveals that the AI prioritizes specific clinical markers, like the lack of hypertension, even more than the standard passage of time. Ultimately, the
# model's "Low" risk response was a calculated victory for her current health status over the biological reality of her age.
#
# === Instance: 141 ===
# LLM response: 'Low'
# Narrative:
# When the AI evaluated the patient’s profile to predict a stroke risk of **"Low,"** it didn’t look at the data the way a human doctor might; instead,
# it acted like a judge weighing different players in a tug-of-war. The strongest "players" pushing the model toward a Low-risk verdict were the
# patient’s healthy physical markers, specifically her **BMI of 23.8** and the fact that she had **no hypertension (0)** or **heart disease (0)**. These
# specific tokens acted as heavy anchors for the model's decision, signaling a baseline of physical health that far outweighed other factors.
# Interestingly, while the patient’s age of **59.0** and her status as a smoker (**smokes**) tried to pull the model toward a "High" risk prediction,
# their influence was significantly weaker than the positive health markers. The model essentially "decided" that being a non-hypertensive woman with a
# healthy weight was more protective than the risks posed by smoking at middle age. Even the patient's **"Rural"** residence and **"Private"** work type
# added small nudges toward the Low-risk outcome, while common factors like glucose levels barely registered on the AI's radar. In the end, the model
# arrived at "Low" because the absence of chronic conditions (the zeros) created a much stronger statistical signal than the presence of lifestyle
# risks.  **Summary:** The AI prioritized healthy physical indicators like a normal BMI and the absence of hypertension over known risks like smoking
# and age to conclude the patient was at low risk for a stroke.
#
# === Instance: 17 ===
# LLM response: 'High'
# Narrative:
# Imagine the AI as a seasoned investigator looking for "clues" to solve the mystery of a patient’s health risk. In this case, the most incriminating
# evidence was the word **"smokes,"** which acted like a flashing red light, immediately pushing the AI toward a "High" risk conclusion. Following
# closely behind were the patient’s age of **75.0**, a high glucose level of **221.29**, and the presence of hypertension (marked by the number **1**),
# which all reinforced the AI's concern. Interestingly, labels like "gender" or the word "Patient" actually worked in the opposite direction; they were
# seen as generic background noise that temporarily distracted the AI from the specific medical dangers. The model largely ignored the fact that the
# patient had no heart disease (the value **0**), focusing instead on the combination of age and lifestyle. Essentially, the AI "connected the dots"
# between smoking, elderly status, and blood pressure to reach its verdict. By weighing these specific physical threats far more heavily than the
# administrative details of the profile, the model confidently flagged the patient as high risk.  **Summary:** The AI reached a "High" risk verdict by
# prioritizing critical physiological red flags like smoking status, advanced age, and hypertension over generic labels or the absence of heart disease.
#
# === Instance: 196 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated this patient’s record, it acted like a digital detective looking for the most alarming "clues" to justify its "High Risk"
# prediction. The most powerful piece of evidence was the number **70.0**, which held the highest possible influence; the model recognized that advanced
# age is a primary driver of stroke risk. Closely following this were the physical markers of **45.5** (BMI) and **242.52** (glucose), which the AI
# flagged as critical red flags for metabolic health. It also placed significant weight on the word **formerly**, identifying a past history of smoking
# as a lingering danger even if the habit had stopped. Interestingly, the numerical value **1** (indicating hypertension) was a much stronger signal
# than the word "hypertension" itself, showing the model's preference for direct clinical data. While clinical factors drove the "High" rating, general
# labels like **gender:** and **Patient** actually pushed *against* that conclusion, suggesting the model found them too vague to be useful. By ignoring
# these generic labels and focusing intensely on the specific high-value numbers, the model built a coherent case for a high-risk diagnosis. In short,
# the AI’s decision was dominated by a "big three" of age, weight, and blood sugar, which outweighed all other demographic details.  **Summary:** The AI
# predicted a high risk by prioritizing specific clinical numbers—age (70), BMI (45.5), and glucose (242.52)—over general descriptive words. It viewed
# the patient’s history of smoking as a major contributor while finding general labels like "gender" to be distracting or unhelpful data.
#
# === Instance: 255 ===
# LLM response: 'Low'
# Narrative:
# When the AI was asked to evaluate this patient, it acted like a digital detective looking for specific "clues" that signaled safety. Interestingly,
# the model was most convinced the patient was at **Low** risk not by her age, but by her physical measurements: her BMI of **17.7** and her glucose
# level of **77.59** were the strongest drivers toward a healthy prediction. The AI also leaned heavily on the fact that she was **Female** and had
# zeros listed for both **hypertension** and **heart disease**, treating these as powerful "green lights" for health. Interestingly, while we might
# expect age to be a major factor, the value **52.0** actually had a very small impact, suggesting the model found her lack of medical conditions more
# telling than her birthday. On the other hand, the words "**Patient profile:**" at the very bottom of the list actually confused the model slightly,
# pulling it away from a confident answer as if the formatting itself was a distraction. The model also showed a nuanced "internal debate" regarding her
# history as a smoker; while the word "**formerly**" helped confirm a low-risk status, the word "**smoked**" pushed back in the other direction.
# Ultimately, the combination of a healthy weight, normal blood sugar, and a clean medical history outweighed any other factors.  **Summary:** The AI
# predicted a "Low" risk primarily because the patient’s specific health metrics (BMI and glucose) and the absence of pre-existing conditions were
# highly persuasive, while demographic details like age and marital status played a surprisingly minor role.
#
# === Instance: 30 ===
# LLM response: 'High'
# Narrative:
# When the model reviewed this patient’s profile, it acted like a digital detective looking for the most alarming "red flags" to determine stroke risk.
# The heaviest weight by far was placed on the word **"smokes,"** which the model identified as the single most critical predictor for a "High" risk
# rating. Close behind were the physical markers of strain: a high **BMI of 44.2**, the presence of **hypertension (indicated by the '1')**, and a
# relatively high **age of 57.0**. Interestingly, while the high **glucose level (212.08)** was an important factor, it was the combination of lifestyle
# and cardiovascular pressure that truly drove the model's decision. On the other hand, the model treated labels like "gender" or "ever_married" as
# noise, actually finding them slightly distracting or unhelpful in making a clinical prediction. This analysis reveals that the model isn't just
# reading a list; it is prioritizing clear medical vulnerabilities over general demographic information. Essentially, the model "saw" a patient whose
# heart and blood vessels were under significant stress and ignored the social filler to reach its conclusion.  **Summary:** The model predicted a
# "High" risk primarily because it prioritized the patient's smoking status, high BMI, and hypertension as the most aggressive indicators of danger. It
# effectively filtered out less relevant social data, like gender and marital status, to focus on these critical health "red flags."
#
# === Instance: 302 ===
# LLM response: 'Low'
# Narrative:
# When the AI analyzed this patient, it acted like a digital juror weighing evidence to reach the verdict of "Low" risk. The most powerful witness in
# the room was the word **"never"** from the smoking status; its perfect score of 1.0 indicates it was the primary reason the AI felt confident in a
# low-risk prediction. Close behind were the two **"0"** values, which told the model the patient was free from the heavy burdens of hypertension and
# heart disease. The AI also found reassurance in the specific health numbers, viewing the BMI of **25.1** and the age of **44.0** as protective factors
# that supported a healthy outlook. Interestingly, the label **"heart_disease:"** actually had a negative value, suggesting that just seeing the mention
# of "disease" briefly made the model more cautious before it processed the "0" that followed. Even physical facts like the patient’s **glucose level**
# and **Rural** location helped nudge the needle toward the final "Low" result. Meanwhile, labels like "gender" and "work_type" were relegated to the
# background, having almost no impact on the final decision.   **Summary:** The AI primarily reached its "Low" risk conclusion because the patient
# "never" smoked and lacked chronic conditions like hypertension. These positive health indicators were so strong that they easily outweighed the mere
# mention of risk categories in the patient's profile.
#
# === Instance: 386 ===
# LLM response: 'High'
# Narrative:
# When the AI reviewed this patient’s profile, it acted like a digital detective looking for the most alarming "clues" to justify its "High" risk
# prediction. The most powerful piece of evidence was the number **251.6**, representing the glucose level; this value had the highest influence,
# signaling to the model that the patient’s blood sugar was dangerously elevated. Close behind were the age of **70.0** and the presence of hypertension
# (marked by the value **1**), which acted as a heavy "one-two punch" in the model's decision-making process. Interestingly, while the clinical labels
# like "avg_glucose_level" helped orient the model, the raw numerical data itself carried the most weight in pushing the prediction toward a High-risk
# category. On the other hand, the model seemed to downplay or even get "distracted" by administrative labels like "gender" and "ever_married," which
# actually pulled the prediction slightly away from the final result. Characteristics like being "Male" or "Self-employed" were considered risk factors,
# but they were minor compared to the overwhelming influence of the patient's age and blood sugar. The model essentially ignored the term "bmi" and the
# fact that the patient "never" smoked, focusing instead on the immediate danger posed by the high glucose and seniority. Ultimately, the AI’s decision
# was dominated by a few critical health metrics rather than the full biographical story.  **Summary:** The AI predicted a high stroke risk primarily
# because of three dominant factors: an extremely high glucose level (251.6), the patient's advanced age (70.0), and the presence of hypertension. While
# it considered gender and employment, these specific medical numbers were the "heavy hitters" that drove the final response.
#
# === Instance: 4 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated the patient’s profile, it acted like a digital investigator looking for the most compelling "evidence" to justify a High Risk
# rating. The most dominant piece of evidence was the number **79.0**, which carried the maximum weight; the AI recognized that advanced age is the
# primary driver of stroke risk, making it the anchor for the entire decision. Following closely were the patient’s high blood sugar (**174.12**) and
# the presence of hypertension (marked by the value **1**), which together convinced the model that the cardiovascular system was under significant
# stress. Interestingly, while the AI noted clinical factors like heart disease and glucose levels, it also gave surprising weight to the patient’s
# "Rural" residence and "Self-employed" status as supporting risk factors. Conversely, the model actively pushed back against a high-risk label when it
# saw the value **0** for heart disease and the patient's healthy **BMI**, though these were not strong enough to overturn the overall verdict. The AI
# essentially performed a balancing act where the high-impact trio of age, sugar, and blood pressure outweighed the protective factors of a healthy
# weight and a strong heart. This suggests that the model views age and chronic metabolic issues as the ultimate "deal-breakers" in health forecasting.
# **Summary:** The AI reached a "High Risk" conclusion primarily because of the patient’s age (79.0), high glucose (174.12), and hypertension, which
# acted as the most influential triggers. While a healthy BMI and lack of heart disease tried to pull the score lower, they were statistically
# overshadowed by these more critical clinical red flags.
#
# === Instance: 49 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a digital detective weighing evidence on a scale to reach its "High" risk verdict. The
# most powerful piece of evidence—the heavy weight that tipped the scale instantly—was the word **"smokes,"** which the model flagged as the primary
# driver for its prediction. Close behind were the clinical markers of physical health: a high **BMI of 39.2** and the presence of **hypertension
# (marked as '1')**, both of which the AI strongly associated with stroke risk. Interestingly, while a human doctor might focus heavily on the patient’s
# age or blood glucose, the AI actually treated the **"avg_glucose_level"** and the patient’s **age of 39** as "lowering" factors that pulled the
# prediction away from a high-risk conclusion. It was as if the AI recognized that being relatively young and having a lower glucose level were
# protective traits, but they simply weren't strong enough to outweigh the risks of smoking and high blood pressure. Other details, like the patient
# being **Female** or working a **Private** job, were treated as minor background noise with very little influence on the final result. Ultimately, the
# model’s "High" risk label was a calculated balance where life-threatening habits and physical conditions drowned out the protective benefits of youth.
# **Summary:** The AI reached its "High" risk conclusion by prioritizing smoking status and hypertension as the most critical dangers, ultimately
# deciding that these specific risks outweighed the patient's relatively young age and healthy glucose levels.
#
# === Instance: 500 ===
# LLM response: 'Low'
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a digital detective weighing different clues to reach its "Low" risk verdict. The most
# powerful "green lights" for this decision were the patient’s gender being **Female** and her blood sugar sitting at a stable **77.49**, both of which
# the model strongly associated with lower immediate stroke risk. Interestingly, while things like her "Private" job or living in an "Urban" area played
# minor supporting roles, the AI’s attention was highly concentrated on specific medical markers rather than lifestyle labels.  However, the decision
# wasn’t unanimous; the model had to ignore some "red flags" that tried to pull its prediction toward a "High" risk result. The most significant
# pushback came from her **BMI of 36.0** and the **heart_disease** category, which usually signal higher danger. Surprisingly, the patient’s **age** of
# 56 and her status as someone who **formerly smoked** didn't carry as much weight as one might expect, acting as relatively neutral factors in this
# specific calculation. Ultimately, because the positive influence of her stable glucose and gender far outweighed the negative signals from her BMI,
# the AI concluded she fell into the low-risk category.  **Summary:** The model reached a "Low" risk conclusion primarily because the protective weight
# of the patient’s gender and healthy glucose levels overpowered the clinical concerns regarding her BMI and heart health.
#
# === Instance: 52 ===
# LLM response: 'High'
# Narrative:
# When the AI evaluated this patient’s profile, it acted like a digital detective looking for the most compelling evidence to justify a "High" risk
# prediction. The most powerful "clue" by far was the number **79.0**, which carried the maximum weight in its decision; the model recognized that
# advanced age is a primary driver of stroke risk. Closely following this was the value **1**, signaling a history of heart disease, which acted as a
# secondary confirmation that the patient’s cardiovascular health was under strain. Interestingly, while medical factors like glucose levels and BMI
# pushed the model toward its "High" response, the patient's gender actually tried to pull the model's "mind" in the opposite direction. The token for
# **gender:** had the strongest negative influence, suggesting that being female was a piece of data the model briefly considered as a lowering factor
# before the weight of age and heart disease overwhelmed it. Other lifestyle details, like residing in a **Rural** area or working in the **Private**
# sector, hovered in the middle, providing small nudges rather than major breakthroughs. This shows that the AI primarily values biological "red flags"
# over social or demographic labels when making its final call. Ultimately, the model’s "High" verdict was a tug-of-war where the undeniable reality of
# a 79-year-old heart condition defeated the minor protective associations of other traits.  **Summary:** The AI reached its "High" risk conclusion
# because it prioritized age and heart disease above all else, using those factors as the ultimate deciders while treating the patient's gender as a
# slight counter-argument that was eventually ignored.
#
# === Instance: 600 ===
# LLM response: 'Low'
# Narrative:
# When the medical model looked at this patient’s profile to predict a "Low" stroke risk, it acted much like a digital detective looking for the
# strongest evidence of health. The most powerful piece of evidence was the number **24.0**, representing her age; in the model's logic, youth acted as
# a massive weight anchoring the prediction firmly in the "Low" category. Closely following this were the biological indicators of being **Female** and
# having **never** smoked, which the model viewed as significant protective layers. Interestingly, the model prioritized these specific traits and the
# healthy **23.4** BMI over the technical labels like "work_type" or "bmi" itself, which it largely ignored. Even clinical markers like blood sugar and
# hypertension were secondary players compared to the sheer influence of her age and lifestyle. At the opposite end, the label **gender:** actually
# confused the model slightly, momentarily pulling it away from a confident answer before the data point "Female" corrected its course. This reveals
# that the AI doesn't just read a list; it weights certain "hero" words like age and smoking status far more heavily than the rest. Ultimately, the
# model’s "Low" risk verdict was a story written primarily by the patient’s youth and clean habit history.  **Summary:** The model predicted a "Low"
# risk because it prioritized the patient's young age (24.0), gender (Female), and non-smoking status as the most decisive factors, while clinical
# labels and work history had little to no impact on its decision.
#
# === Instance: 74 ===
# LLM response: 'Low'
# Narrative:
# Imagine an AI as a digital detective trying to solve a medical mystery: "Is this patient at risk?" When our model looked at this 52-year-old woman’s
# profile, it immediately focused on one word above all others: **"never."** Because she had *never* smoked, the AI gained a massive surge of confidence
# in predicting a "Low" risk, as this took one of the most dangerous culprits off the table. The model also saw the two **"0"** entries—representing no
# hypertension and no heart disease—as vital green lights that reinforced its decision. Interestingly, while we might expect age to be a major factor,
# the AI was relatively unimpressed by "52.0," suggesting that having a healthy heart and clean lungs outweighed the number of years lived. Even the
# patient being "Female" and working a "Private" job acted as supporting evidence that pushed the model closer to its final answer. However, the AI
# wasn't mindlessly tallying points; it felt a bit of "doubt" from the word "gender" itself, perhaps because medical risks vary so wildly across
# different populations. In the end, the absence of smoking and chronic disease acted like a heavy weight on a scale, tipping the AI firmly toward a
# "Low" risk prediction.  **Summary:** The model’s "Low" risk prediction was driven primarily by the patient’s non-smoking status and the absence of
# heart disease or hypertension, while factors like age and residence played surprisingly minor roles.
#
# === Instance: 825 ===
# LLM response: 'Low'
# Narrative:
# When the model predicted a "Low" stroke risk for this patient, it acted like a digital weigh-scale, balancing different pieces of information to see
# which way the needle would swing. The most powerful "weights" pushing the model toward a Low-risk conclusion were the zeros next to hypertension and
# heart disease, along with a healthy blood glucose level of 73.75. To the model, these clear biological markers of health acted as strong evidence that
# the patient’s cardiovascular system was stable. On the other hand, the fact that the patient "smokes" and is "59.0" years old acted as heavy counter-
# weights, pulling the model toward a High-risk prediction. Interestingly, the model seemed to view the clinical "0" for hypertension as a more
# definitive signal than the lifestyle risk of smoking. While the patient’s age and smoking status were significant concerns, they were ultimately
# outweighed by the absence of chronic conditions and a healthy BMI. The model's final "Low" verdict was not a sign that it ignored the smoking, but
# rather a calculation that his current medical stats provided a temporary safety net against those risks.  **Summary:** The model reached a "Low" risk
# conclusion because the absence of pre-existing heart conditions and hypertension (represented by the highly influential "0" values) carried more
# weight than the significant risks posed by the patient's age and smoking habit.
#
# === Instance: 86 ===
# LLM response: 'High'
# Narrative:
# When the AI looked at this patient’s profile to determine stroke risk, it acted like a detective focusing on a few "smoking guns" while ignoring the
# background noise. The word **"smokes"** was the most powerful piece of evidence, pushing the model decisively toward a "High" risk rating more than
# any other factor. Close behind were the specific numbers: the age of **61.0**, a BMI of **27.3**, and a blood glucose of **111.81**, which the model
# identified as a cluster of significant physical red flags. Interestingly, the numerical value **"1"** next to heart disease acted as a major alarm
# bell, yet the labels like "gender" or "age" themselves meant almost nothing to the AI's logic. In fact, some details like the patient being "ever
# married" or the "0" for hypertension actually confused the model or pulled it toward a "Low" risk, but these were drowned out by the severity of the
# lifestyle factors. The model essentially performed a weighted balancing act, where the combination of older age and active smoking outweighed the
# absence of high blood pressure. By weighing these specific data points together, the AI concluded that the cumulative weight of the risks necessitated
# a "High" warning.  **Summary:** The AI reached its "High" risk conclusion by prioritizing the patient's smoking status and specific physical
# measurements (age, BMI, and glucose) as the most critical threats. While some factors like a lack of hypertension suggested lower risk, the powerful
# influence of the "smokes" token and the presence of heart disease drove the final prediction.
#
# === Instance: 924 ===
# LLM response: 'Low'
# Narrative:
# Imagine an AI as a clinical detective who weighs pieces of evidence to reach a verdict, in this case, deciding that 74-year-old Mrs. Weaver is at
# "Low" risk for a stroke. When we peek inside the AI’s decision process using TokenSHAP, we see that the word **"never"** (from "never smoked") was the
# most powerful hero in this story, acting as a massive green light for a healthy prediction. Close behind were the two zeros representing the absence
# of hypertension and heart disease, which provided the AI with a strong foundation of medical stability. Interestingly, while Mrs. Weaver’s age of
# **74.0** was a major red flag—the strongest force pushing the model toward a "High" risk rating—it wasn't enough to override her healthy habits. The
# model also took comfort in her **"Female"** gender and her healthy **24.8** BMI, using these as additional evidence that her lifestyle mitigates the
# natural risks of aging. Other details, like her urban residence or marital status, were treated as mere background noise that barely nudged the
# needle. Ultimately, the story the AI tells is one of balance: the "Low" risk verdict was won because her lifelong commitment to not smoking and her
# clear cardiovascular history outweighed the single, unchangeable risk of her age.  **Summary:** The AI reached a "Low" risk conclusion because the
# absence of smoking and chronic diseases acted as dominant positive factors that successfully counteracted the significant biological risk posed by the
# patient's advanced age.

# %% [markdown]
# # 5. Visualisations

# %% [markdown]
# ## 5.1 Shapley value plot of prompt

# %% [markdown]
# custom visualisation function

# %%
def print_colored_text(df, max_width=150):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["shapley_value"].abs().max()

    def get_color(value):
        # 2. Map the value so that 0 is exactly 0.5 (neutral)
        if max_abs == 0:
            norm_value = 0.5
        else:
            norm_value = (value + max_abs) / (2 * max_abs)
            
        if norm_value < 0.5:
            r = int(255 * (norm_value * 2))
            g = int(255 * (norm_value * 2))
            b = 255
        else:
            r = 255
            g = int(255 * (2 - norm_value * 2))
            b = int(255 * (2 - norm_value * 2))
        return r, g, b

    current_width = 0
    for _, row in df.iterrows():
        token = row["token"]
        token_width = len(token) + 1  # +1 for the space
        if current_width + token_width > max_width:
            print()
            current_width = 0
        r, g, b = get_color(row["shapley_value"])
        print(f"\033[38;2;{r};{g};{b}m{token}\033[0m", end=' ')
        current_width += token_width
    print()

def plot_colored_text(df, title="", max_width=0.95, fontsize=11, save_path=None):
    # 1. Calculate max_abs instead of min/max
    max_abs = df["shapley_value"].abs().max()

    # Build lines by measuring real rendered text widths
    fig, ax = plt.subplots(figsize=(14, 2))
    renderer = fig.canvas.get_renderer()

    lines = []
    current_line = []
    current_width = 0.0

    for _, row in df.iterrows():
        # Measure the actual rendered width of this token
        t = ax.text(0, 0, row["token"] + " ", fontsize=fontsize, transform=ax.transAxes)
        bbox = t.get_window_extent(renderer=renderer)
        t.remove()
        token_width = bbox.width / fig.get_window_extent(renderer=renderer).width

        if current_line and current_width + token_width > max_width:
            lines.append(current_line)
            current_line = []
            current_width = 0.0
        current_line.append((row, token_width))
        current_width += token_width

    if current_line:
        lines.append(current_line)

    plt.close(fig)

    # Now draw the real figure
    num_lines = len(lines)
    fig, ax = plt.subplots(figsize=(14, num_lines * 0.5 + 1.5))
    ax.axis('off')

    y_step = 0.85 / (num_lines)
    y_pos = 0.95

    for line in lines:
        x_pos = 0.02
        for row, token_width in line:
            # 2. Map the value for the coolwarm colormap
            if max_abs == 0:
                norm_value = 0.5
            else:
                norm_value = (row["shapley_value"] + max_abs) / (2 * max_abs)
                
            color = plt.cm.coolwarm(norm_value)
            ax.text(x_pos, y_pos, row["token"], color=color, fontsize=fontsize,
                    ha='left', va='top', transform=ax.transAxes)
            x_pos += token_width
        y_pos -= y_step

    if title:
        ax.set_title(title, fontsize=13, pad=10)

    # 3. Update the colorbar to be strictly symmetrical (-max_abs to max_abs)
    sm = plt.cm.ScalarMappable(
        cmap=plt.cm.coolwarm, 
        norm=plt.Normalize(vmin=-max_abs, vmax=max_abs)
    )
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, orientation='horizontal', pad=0.05)
    cbar.set_label('Shapley Value', fontsize=11)

    plt.tight_layout()
    
    # Save the figure if a path is provided
    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        
    plt.show()

# %%
# 1. Update the folder path to include the 'shapley' subfolder
save_dir = os.path.join('visualisations', 'shapley')
os.makedirs(save_dir, exist_ok=True)

for instance_id, df in sorted(dfs.items()):
    print(f"\n=== instance_{instance_id} ===")
    df_ordered = df.sort_values("position")  # original sentence order

    # Print to terminal
    print_colored_text(df_ordered)
    
    # 2. Point the save_file to the new directory
    save_file = os.path.join(save_dir, f"shapley_values_{instance_id}.svg")

    # Plot and save
    plot_colored_text(df_ordered, title=f"instance_{instance_id}", save_path=save_file)
# Out:
# === instance_0 ===
# Patient profile: gender: Male age: 67.0 hypertension: 0 heart_disease: 1 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 228.69 bmi: 36.6 smoking_status: formerly smoked
# === instance_4 ===
# Patient profile: gender: Female age: 79.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Self-employed Residence_type: Rural
# avg_glucose_level: 174.12 bmi: 24.0 smoking_status: never smoked
# === instance_17 ===
# Patient profile: gender: Male age: 75.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 221.29 bmi: 25.8 smoking_status: smokes
# === instance_30 ===
# Patient profile: gender: Male age: 57.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 212.08 bmi: 44.2 smoking_status: smokes
# === instance_49 ===
# Patient profile: gender: Female age: 39.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 58.09 bmi: 39.2 smoking_status: smokes
# === instance_52 ===
# Patient profile: gender: Female age: 79.0 hypertension: 0 heart_disease: 1 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 127.29 bmi: 27.7 smoking_status: never smoked
# === instance_74 ===
# Patient profile: gender: Female age: 52.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 96.59 bmi: 26.4 smoking_status: never smoked
# === instance_86 ===
# Patient profile: gender: Male age: 61.0 hypertension: 0 heart_disease: 1 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 111.81 bmi: 27.3 smoking_status: smokes
# === instance_141 ===
# Patient profile: gender: Female age: 59.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 116.44 bmi: 23.8 smoking_status: smokes
# === instance_196 ===
# Patient profile: gender: Male age: 70.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 242.52 bmi: 45.5 smoking_status: formerly smoked
# === instance_255 ===
# Patient profile: gender: Female age: 52.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 77.59 bmi: 17.7 smoking_status: formerly smoked
# === instance_302 ===
# Patient profile: gender: Male age: 44.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 81.84 bmi: 25.1 smoking_status: never smoked
# === instance_386 ===
# Patient profile: gender: Male age: 70.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Self-employed Residence_type: Urban
# avg_glucose_level: 251.6 bmi: 27.1 smoking_status: never smoked
# === instance_500 ===
# Patient profile: gender: Female age: 56.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 77.49 bmi: 36.0 smoking_status: formerly smoked
# === instance_600 ===
# Patient profile: gender: Female age: 24.0 hypertension: 0 heart_disease: 0 ever_married: No work_type: Self-employed Residence_type: Rural
# avg_glucose_level: 115.03 bmi: 23.4 smoking_status: never smoked
# === instance_825 ===
# Patient profile: gender: Male age: 59.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Govt_job Residence_type: Rural
# avg_glucose_level: 73.75 bmi: 27.3 smoking_status: smokes
# === instance_924 ===
# Patient profile: gender: Female age: 74.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 87.11 bmi: 24.8 smoking_status: never smoked
# === instance_1295 ===
# Patient profile: gender: Male age: 60.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Rural
# avg_glucose_level: 101.34 bmi: 32.8 smoking_status: never smoked
# === instance_1322 ===
# Patient profile: gender: Female age: 55.0 hypertension: 1 heart_disease: 0 ever_married: Yes work_type: Private Residence_type: Urban
# avg_glucose_level: 206.4 bmi: 54.8 smoking_status: never smoked
# === instance_1362 ===
# Patient profile: gender: Female age: 72.0 hypertension: 0 heart_disease: 0 ever_married: Yes work_type: Self-employed Residence_type: Rural
# avg_glucose_level: 103.25 bmi: 26.9 smoking_status: formerly smoked

# %% [markdown]
# ## 5.2 Narrative evaluation

# %%
os.makedirs("visualisations/evaluation", exist_ok=True)

# %% [markdown]
# ### Plot 1: Evaluation heatmaps

# %%
# ---------------------------------------------------------------------------
# Helper — extract scores from a single entry
# Returns: {aspect: {model: score}}
# ---------------------------------------------------------------------------
def extract_scores(entry: dict, persona: str) -> dict:
    scores = {}
    for aspect in ASPECTS:
        scores[aspect] = {}
        aspect_data = entry["evaluations"][persona].get(aspect, {})
        for model in MODELS:
            model_data = aspect_data.get(model, {})
            scores[aspect][model] = model_data.get("final_score", None)
    return scores

# %%
# ---------------------------------------------------------------------------
# PLOT 1 — Per-instance heatmaps
# Rows: judge models + aggregate row, Cols: aspects
# One image per persona, one heatmap per instance
# ---------------------------------------------------------------------------
short_models = [m.split("/")[-1] for m in MODELS]
row_labels   = short_models + ["Aggregate"]
n_instances  = len(instances)

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated
                       if persona in e.get("evaluations", {})}

    fig1, axes1 = plt.subplots(n_instances, 1, figsize=(6, 2.2 * n_instances))
    if n_instances == 1:
        axes1 = [axes1]

    for ax_idx, instance in enumerate(instances):
        ax    = axes1[ax_idx]
        entry = persona_entries.get(instance)

        if entry is None:
            ax.set_visible(False)
            continue

        scores = extract_scores(entry, persona)

        # Individual judge rows — same as before
        judge_matrix = np.array([
            [scores[aspect].get(model, np.nan) for aspect in ASPECTS]
            for model in MODELS
        ], dtype=float)

        # Aggregate row
        agg_row = np.array([
            entry["evaluations"][persona].get(aspect, {}).get("aggregate_score", np.nan)
            for aspect in ASPECTS
        ], dtype=float).reshape(1, -1)

        matrix = np.vstack([judge_matrix, agg_row])

        # Draw dividing line between judges and aggregate
        # by using a masked annotation style: bold for aggregate row
        sns.heatmap(
            matrix,
            ax=ax,
            annot=True,
            fmt=".1f",
            vmin=1, vmax=5,
            cmap="RdYlGn",
            xticklabels=[a.capitalize() for a in ASPECTS],
            yticklabels=row_labels,
            linewidths=0.5,
            linecolor="white",
            cbar=False,
        )

        # Bold the aggregate row label and draw a separator line
        yticklabels = ax.get_yticklabels()
        yticklabels[-1].set_fontweight("bold")
        ax.set_yticklabels(yticklabels)

        # Horizontal separator above aggregate row
        ax.axhline(y=len(MODELS), color="black", linewidth=1.5)

        ax.set_title(f"Instance {instance}", fontsize=11,
                     fontweight="bold", pad=8)
        ax.set_ylabel("")
        ax.set_xlabel("Aspect")

    fig1.suptitle(
        f"Per-Instance Evaluation Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig1.tight_layout()
    fig1.subplots_adjust(top=1)

    filename = f"visualisations/evaluation/evaluation_heatmaps_{persona}.svg"
    fig1.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig1)
# Out:
# Saved visualisations/evaluation/evaluation_heatmaps_doctor.svg
# Saved visualisations/evaluation/evaluation_heatmaps_doctor_elaborate.svg
# Saved visualisations/evaluation/evaluation_heatmaps_expert_judge.svg
# Saved visualisations/evaluation/evaluation_heatmaps_patient.svg
# Saved visualisations/evaluation/evaluation_heatmaps_patient_elaborate.svg

# %% [markdown]
# ####    Plot 1b: Aggregate heatmap

# %%
# ---------------------------------------------------------------------------
# PLOT 1b — Heatmap: instances (rows) x aspects (cols)
# Value: aggregate_score averaged across personas
# Good for spotting outlier instances at a glance
# ---------------------------------------------------------------------------

# Build: instance -> aspect -> mean aggregate score across personas
instance_aspect_means = {}
for instance in instances:
    instance_aspect_means[instance] = {}
    for aspect in ASPECTS:
        scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in log_evaluated
            if e["instance_index"] == instance
            for persona in personas
            if persona in e.get("evaluations", {})
            and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        instance_aspect_means[instance][aspect] = np.mean(scores) if scores else np.nan
        
matrix = np.array([
    [instance_aspect_means[inst][aspect] for aspect in ASPECTS]
    for inst in instances
])

fig, ax = plt.subplots(figsize=(5, max(6, len(instances) * 0.4)))
sns.heatmap(
    matrix,
    ax=ax,
    annot=True,
    fmt=".1f",
    vmin=1, vmax=5,
    cmap="RdYlGn",
    xticklabels=[a.capitalize() for a in ASPECTS],
    yticklabels=[f"#{inst}" for inst in instances],
    linewidths=0.4,
    cbar_kws={"label": "Aggregate score"},
)
ax.set_title("Aggregate Score Heatmap", fontweight="bold")
ax.set_xlabel("Aspect")
ax.set_ylabel("Instance")

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_heatmap.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_heatmap.svg")
plt.close(fig)
# Out:
# Saved aggregate_heatmap.svg

# %% [markdown]
# ### Plot 2: Average scores (over all instances) per Judge and Persona

# %%
rows = []
for e in log_evaluated:
    instance = e["instance_index"]
    for persona, aspects in e["evaluations"].items():
        for aspect, models_data in aspects.items():
            for model in MODELS:
                data = models_data.get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                rows.append({
                    "instance": instance,
                    "persona": persona.replace("_", " ").title(),
                    "aspect": aspect.capitalize(),
                    "model": model.split("/")[-1],
                    "score": score,
                })

df_long = pd.DataFrame(rows).dropna(subset=["score"])

# %% [markdown]
# strip plot

# %%
fig, axes = plt.subplots(1, len(ASPECTS), figsize=(5 * len(ASPECTS), 5), sharey=True)

for i, (ax, aspect) in enumerate(zip(axes, ASPECTS)):
    data = df_long[df_long["aspect"] == aspect.capitalize()]
    sns.stripplot(
        data=data, x="persona", y="score", hue="model",
        dodge=True, jitter=0.15, ax=ax, alpha=0.5, size=6,
    )
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("")
    ax.set_ylabel("Score (1-5)" if i == 0 else "")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.tick_params(axis="x", rotation=20)

    if aspect.lower() != "plausibility":
        ax.legend_.remove()
    else:
        ax.legend(title="Judge", fontsize=7, title_fontsize=8, loc="lower right")

fig.suptitle("Score Distribution per Persona & Judge", fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/strip_all_judges.svg", dpi=150, bbox_inches="tight")
plt.close(fig)

# %% [markdown]
# bar chart

# %%
cmap_models = matplotlib.colormaps.get_cmap("tab10")
colors_personas = [cmap_models(i / len(personas)) for i in range(len(personas))]

n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
bar_fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

for model in MODELS:
    short_model = model.split("/")[-1]

    fig_bar, ax_bar = plt.subplots(figsize=(bar_fig_width, 5))

    persona_aspect_means = {}
    for persona in personas:
        persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
        means = {}
        for aspect in ASPECTS:
            scores = [
                e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score")
                for e in persona_entries
                if isinstance(e["evaluations"][persona].get(aspect, {}).get(model, {}), dict)
                and e["evaluations"][persona].get(aspect, {}).get(model, {}).get("final_score") is not None
            ]
            means[aspect] = np.mean(scores) if scores else 0
        persona_aspect_means[persona] = means

    x = np.arange(len(ASPECTS))

    for i, (persona, means) in enumerate(persona_aspect_means.items()):
        values = [means[a] for a in ASPECTS]
        offset = (i - n_personas / 2 + 0.5) * width
        bars = ax_bar.bar(
            x + offset, values, width,
            label=persona.replace("_", " ").title(),
            color=colors_personas[i], alpha=0.85
        )
        for bar, val in zip(bars, values):
            ax_bar.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.2f}", ha="center", va="bottom", fontsize=9
            )

    ax_bar.set_xticks(x)
    ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
    ax_bar.set_ylim(0.5, 5.5)
    ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
    ax_bar.set_ylabel("Average score over all instances")
    ax_bar.set_title(f"Average Scores per Aspect & Persona — {short_model}", fontweight="bold")
    ax_bar.legend()
    ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

    fig_bar.tight_layout()
    filename_bar = f"visualisations/evaluation/evaluation_summary_bar_{short_model}.svg"
    fig_bar.savefig(filename_bar, dpi=150, bbox_inches="tight")
    print(f"Saved {filename_bar}")
    plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_summary_bar_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_summary_bar_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_summary_bar_grok-4.20.svg

# %% [markdown]
# #### Plot 2b: Average scores (over all instances) of aggregated scores per Persona

# %% [markdown]
# The aggregate score is the majority-voted score across all judge models for a given aspect and instance — so if 3 out of 5 models give a score of 2, the aggregate score is 2. The averaged aggregate score in the bar chart then takes these per-instance aggregate scores and averages them across all 20 instances to give a single summary score per aspect per persona.

# %%
n_personas = len(personas)
width = min(0.25, 0.8 / n_personas)
fig_width = max(6, n_personas * len(ASPECTS) * 0.6 + 2)

cmap   = matplotlib.colormaps.get_cmap("tab10")
colors = [cmap(i / len(personas)) for i in range(len(personas))]

persona_aspect_means = {}
for persona in personas:
    persona_entries = [e for e in log_evaluated if persona in e.get("evaluations", {})]
    means = {}
    for aspect in ASPECTS:
        agg_scores = [
            e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
            for e in persona_entries
            if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
        ]
        means[aspect] = np.mean(agg_scores) if agg_scores else 0
    persona_aspect_means[persona] = means

x = np.arange(len(ASPECTS))

fig_bar, ax_bar = plt.subplots(figsize=(fig_width, 5))

for i, (persona, means) in enumerate(persona_aspect_means.items()):
    values = [means[a] for a in ASPECTS]
    offset = (i - n_personas / 2 + 0.5) * width
    bars = ax_bar.bar(x + offset, values, width,
                      label=persona.replace("_", " ").title(),
                      color=colors[i], alpha=0.85)
    for bar, val in zip(bars, values):
        ax_bar.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                    f"{val:.2f}", ha="center", va="bottom", fontsize=8)

ax_bar.set_xticks(x)
ax_bar.set_xticklabels([a.capitalize() for a in ASPECTS])
ax_bar.set_ylim(0.5, 5.5)
ax_bar.set_xlim(-0.5, len(ASPECTS) - 0.5)
ax_bar.set_ylabel("Average score over all instances")
ax_bar.set_title("Average Aggregate Scores per Aspect & Persona", fontweight="bold")
ax_bar.legend()
ax_bar.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig_bar.tight_layout()
fig_bar.savefig("visualisations/evaluation/evaluation_summary_bar.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_summary_bar.svg")
plt.close(fig_bar)
# Out:
# Saved visualisations/evaluation/evaluation_summary_bar.svg

# %% [markdown]
# ### Plot 3: Average scores (over all instances) of aggregated scores per Persona

# %%
# ---------------------------------------------------------------------------
# PLOT 3 — Single bar chart: average aggregate score per aspect
# Averaged across all instances AND all personas — the headline result
# ---------------------------------------------------------------------------
aspect_means = {}
aspect_sems  = {}

for aspect in ASPECTS:
    scores = [
        e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
        for e in log_evaluated
        for persona in personas
        if persona in e.get("evaluations", {})
        and e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
    ]
    aspect_means[aspect] = np.mean(scores)
    aspect_sems[aspect]  = np.std(scores, ddof=1) / np.sqrt(len(scores))

colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
fig, ax = plt.subplots(figsize=(5, 5))

x = np.arange(len(ASPECTS))
bars = ax.bar(
    x,
    [aspect_means[a] for a in ASPECTS],
    yerr=[aspect_sems[a] for a in ASPECTS],
    color=colors_aspects,
    alpha=0.85,
    capsize=5,
    width=0.5,
)
for bar, aspect in zip(bars, ASPECTS):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + aspect_sems[aspect] + 0.08,
        f"{aspect_means[aspect]:.2f}",
        ha="center", va="bottom", fontsize=11, fontweight="bold"
    )

ax.set_xticks(x)
ax.set_xticklabels([a.capitalize() for a in ASPECTS], fontsize=12)
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Average aggregate score (1–5)", fontsize=11)
ax.set_title("Average Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_headline.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_headline.svg")
plt.close(fig)
# Out:
# Saved aggregate_headline.svg

# %% [markdown]
# ### Plot 4: Per persona and instance comparison between llm judges

# %%
short_models = [m.split("/")[-1] for m in MODELS]
bar_width    = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

for persona in personas:
    persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, model in enumerate(MODELS):
            short_model = short_models[k]
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(MODELS) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_model,
                color=colors[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors[k], label=short_models[k])
        for k in range(len(MODELS))
    ]
    fig.legend(handles=handles, title="Judge Model", fontsize=8,
               loc="lower center", ncol=len(MODELS),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-LLM Scores — {persona.replace('_', ' ').title()}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_llm_scores_{persona}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_llm_scores_doctor.svg
# Saved visualisations/evaluation/evaluation_llm_scores_doctor_elaborate.svg
# Saved visualisations/evaluation/evaluation_llm_scores_expert_judge.svg
# Saved visualisations/evaluation/evaluation_llm_scores_patient.svg
# Saved visualisations/evaluation/evaluation_llm_scores_patient_elaborate.svg

# %% [markdown]
# ### Plot 5: Per llm judge and instance comparison between personas

# %%
short_personas = [p.replace("_", " ").title() for p in personas]
bar_width      = 0.15
colors_p = ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B2"]

for model in MODELS:
    short_model = model.split("/")[-1]

    fig, axes = plt.subplots(len(ASPECTS), 1, figsize=(14, 5 * len(ASPECTS)), sharey=True)

    if len(ASPECTS) == 1:
        axes = [axes]

    for ax, aspect in zip(axes, ASPECTS):
        x_positions = np.arange(len(instances))

        for k, persona in enumerate(personas):
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            scores = []
            for instance in instances:
                entry = persona_entries.get(instance)
                if entry:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    scores.append(score if score is not None else 0)
                else:
                    scores.append(0)

            offset = (k - len(personas) / 2 + 0.5) * bar_width
            bars = ax.bar(
                x_positions + offset, scores,
                width=bar_width,
                label=short_personas[k],
                color=colors_p[k],
                alpha=0.85,
            )

            for bar, score in zip(bars, scores):
                if score > 0:
                    ax.text(
                        bar.get_x() + bar.get_width() / 2,
                        bar.get_height() + 0.05,
                        str(int(score)),
                        ha="center", va="bottom", fontsize=7
                    )

        ax.set_xticks(x_positions)
        ax.set_xticklabels([f"#{idx}" for idx in instances], fontsize=9)
        ax.set_title(aspect.capitalize(), fontweight="bold")
        ax.set_xlabel("Instance")
        ax.set_ylabel("Score (1-5)")
        ax.set_ylim(0.5, 5.5)
        ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
        ax.grid(axis="y", linestyle="--", alpha=0.4)

    handles = [
        mpatches.Patch(color=colors_p[k], label=short_personas[k])
        for k in range(len(personas))
    ]
    fig.legend(handles=handles, title="Persona", fontsize=8,
               loc="lower center", ncol=len(personas),
               bbox_to_anchor=(0.5, -0.05))

    fig.suptitle(
        f"Per-Persona Scores — {short_model}",
        fontsize=14, fontweight="bold", y=1.02
    )
    fig.tight_layout()

    filename = f"visualisations/evaluation/evaluation_persona_scores_{short_model}.svg"
    fig.savefig(filename, dpi=150, bbox_inches="tight")
    print(f"Saved {filename}")
    plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_persona_scores_gpt-5.4.svg
# Saved visualisations/evaluation/evaluation_persona_scores_gemini-3.1-pro-preview.svg
# Saved visualisations/evaluation/evaluation_persona_scores_claude-sonnet-4.6.svg
# Saved visualisations/evaluation/evaluation_persona_scores_grok-4.20.svg

# %% [markdown]
# ####    Plot 5b: Aggregate scores per persona

# %%
# ---------------------------------------------------------------------------
# PLOT 5b — Aggregate scores per instance, coloured by persona
# 3 subplots (one per aspect), one figure total
# Replaces the per-persona loop with a single comparable figure
# ---------------------------------------------------------------------------
colors_p = ["#4C72B0", "#DD8452", "#55A868", "#C44E52", "#8172B2"]
bar_width = 0.15  # Changed from 0.25 to 0.15 for more spacing

# Matched figsize to your second plot (14 width) to ensure identical scaling
fig, axes = plt.subplots(len(ASPECTS), 1,
                         figsize=(14, 5 * len(ASPECTS)),
                         sharey=True)

if len(ASPECTS) == 1:
    axes = [axes]

for ax, aspect in zip(axes, ASPECTS):
    x_positions = np.arange(len(instances))

    for k, persona in enumerate(personas):
        persona_entries = {e["instance_index"]: e for e in log_evaluated
                           if persona in e.get("evaluations", {})}
        scores = []
        for instance in instances:
            entry = persona_entries.get(instance)
            if entry:
                val = entry["evaluations"][persona].get(
                    aspect, {}).get("aggregate_score")
                scores.append(val if val is not None else 0)
            else:
                scores.append(0)

        offset = (k - len(personas) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=persona.replace("_", " ").title(),
            color=colors_p[k % len(colors_p)],
            alpha=0.85,
        )
        
        for bar, score in zip(bars, scores):
                    if score > 0:
                        ax.text(
                            bar.get_x() + bar.get_width() / 2,
                            bar.get_height() + 0.05,
                            f"{score:.1f}",
                            ha="center", 
                            va="bottom", 
                            fontsize=6,    # Slightly smaller font (optional)
                            rotation=90    # Rotates the text vertically
                        )

    ax.set_xticks(x_positions)
    # Replaced rotation=45 with flat text to match your second plot, 
    # but you can add it back if your labels overlap
    ax.set_xticklabels([f"#{inst}" for inst in instances],
                       fontsize=9) 
    ax.set_title(aspect.capitalize(), fontweight="bold")
    ax.set_xlabel("Instance")
    ax.set_ylabel("Aggregate score (1–5)")
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

handles = [
    mpatches.Patch(color=colors_p[k % len(colors_p)],
                   label=personas[k].replace("_", " ").title())
    for k in range(len(personas))
]
fig.legend(handles=handles, title="Persona", fontsize=8,
           loc="lower center", ncol=len(personas),
           bbox_to_anchor=(0.5, -0.05))

fig.suptitle(
    "Aggregate Scores per Instance & Persona",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_persona_per_instance.svg",
            dpi=150, bbox_inches="tight")
print("Saved aggregate_persona_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_persona_per_instance.svg

# %% [markdown]
# ### Plot 6: All metrics averaged per Persona, Judge, Instance

# %%
n_cols = 4
n_rows = math.ceil(len(instances) / n_cols)
short_models = [m.split("/")[-1] for m in MODELS]
bar_width = 0.15
colors       = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

fig, axes = plt.subplots(n_rows, n_cols, figsize=(6 * n_cols, 5 * n_rows), sharey=True)
axes_flat  = axes.flatten()

for ax in axes_flat[len(instances):]:
    ax.set_visible(False)

for ax, instance in zip(axes_flat, instances):
    x_positions = np.arange(len(personas))

    for k, model in enumerate(MODELS):
        short_model = short_models[k]
        scores = []

        for persona in personas:
            persona_entries = {e["instance_index"]: e for e in log_evaluated if persona in e.get("evaluations", {})}
            entry = persona_entries.get(instance)
            if entry:
                aspect_scores = []
                for aspect in ASPECTS:
                    model_data = entry["evaluations"][persona].get(aspect, {}).get(model, {})
                    score = model_data.get("final_score") if isinstance(model_data, dict) else None
                    if score is not None:
                        aspect_scores.append(score)
                scores.append(np.mean(aspect_scores) if aspect_scores else 0)
            else:
                scores.append(0)

        offset = (k - len(MODELS) / 2 + 0.5) * bar_width
        bars = ax.bar(
            x_positions + offset, scores,
            width=bar_width,
            label=short_model,
            color=colors[k],
            alpha=0.85,
        )

        for bar, score in zip(bars, scores):
            if score > 0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    bar.get_height() + 0.05,
                    f"{score:.1f}",
                    ha="center", va="bottom", fontsize=6
                )

    ax.set_xticks(x_positions)
    ax.set_xticklabels(
        [p.replace("_", " ").title() for p in personas],
        fontsize=8
    )
    ax.set_title(f"Instance #{instance}", fontweight="bold", fontsize=10)
    ax.set_ylim(0.5, 5.5)
    ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
    ax.grid(axis="y", linestyle="--", alpha=0.4)

for ax in axes_flat[::n_cols]:
    ax.set_ylabel("Avg. score across all aspects")

handles = [
    mpatches.Patch(color=colors[k], label=short_models[k])
    for k in range(len(MODELS))
]
fig.legend(handles=handles, title="Judge Model", fontsize=8,
            loc="lower center", ncol=len(MODELS),
            bbox_to_anchor=(0.5, -0.02))

fig.suptitle(
    "Average score across all aspects per Persona, Judge and Instance\n"
    "(faithfulness, helpfulness and plausibility averaged)",
    fontsize=14, fontweight="bold", y=1.02
)
fig.tight_layout()
fig.savefig("visualisations/evaluation/evaluation_faceted.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/evaluation_faceted.svg")
plt.close(fig)
# Out:
# Saved visualisations/evaluation/evaluation_faceted.svg

# %% [markdown]
# ### Plot 7: Score distribution per judge across all aspects and personas

# %%
short_models = [m.split("/")[-1] for m in MODELS]

fig, axes = plt.subplots(1, len(MODELS), figsize=(4 * len(MODELS), 4), sharey=True)

for ax, model in zip(axes, MODELS):
    short_model = model.split("/")[-1]
    scores = []

    for e in log_evaluated:
        for persona in personas:
            if persona not in e.get("evaluations", {}):
                continue
            for aspect in ASPECTS:
                data = e["evaluations"][persona].get(aspect, {}).get(model, {})
                score = data.get("final_score") if isinstance(data, dict) else None
                if score is not None:
                    scores.append(score)

    ax.hist(scores, bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
            color="#4C72B0", edgecolor="white", alpha=0.85)
    ax.set_title(short_model, fontweight="bold", fontsize=9)
    ax.set_xlabel("Score")
    ax.set_ylabel("Count" if ax == axes[0] else "")
    ax.set_xticks([1, 2, 3, 4, 5])
    ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)

fig.suptitle("Score Distribution per Judge (all aspects & personas)",
             fontsize=14, fontweight="bold", y=1.02)
fig.tight_layout()
fig.savefig("visualisations/evaluation/score_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved visualisations/evaluation/score_distribution.svg")
# Out:
# Saved visualisations/evaluation/score_distribution.svg

# %% [markdown]
# ####    Plot 7b: Aggregate score distribution

# %%
# ---------------------------------------------------------------------------
# PLOT 7b — Distribution of aggregate scores across all instances,
# aspects and personas — shows overall calibration of the pipeline
# ---------------------------------------------------------------------------
all_agg_scores = [
    e["evaluations"][persona].get(aspect, {}).get("aggregate_score")
    for e in log_evaluated
    for persona in personas
    if persona in e.get("evaluations", {})
    for aspect in ASPECTS
    if e["evaluations"][persona].get(aspect, {}).get("aggregate_score") is not None
]

fig, ax = plt.subplots(figsize=(5, 4))
ax.hist(
    all_agg_scores,
    bins=[0.5, 1.5, 2.5, 3.5, 4.5, 5.5],
    color="#4C72B0", edgecolor="white", alpha=0.85
)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xlabel("Aggregate score", fontsize=11)
ax.set_ylabel("Count", fontsize=11)
ax.set_title("Aggregate Score Distribution", fontweight="bold")
ax.axvline(x=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.grid(axis="y", linestyle="--", alpha=0.3)

mean_agg = np.mean(all_agg_scores)
ax.axvline(x=mean_agg, color="#C44E52", linestyle="-", linewidth=1.5, label=f"Mean = {mean_agg:.2f}")
ax.legend(fontsize=9)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_distribution.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_distribution.svg")
plt.close(fig)
# Out:
# Saved aggregate_distribution.svg

# %% [markdown]
# ### Plot 8: Per instance aggregate scores per aspect

# %%
# ---------------------------------------------------------------------------
# PLOT 8 — Per-instance aggregate scores per aspect
# Aggregate_score averaged across personas, shown per instance
# Primary result figure: shows narrative quality across the 20 instances
# ---------------------------------------------------------------------------
colors_aspects = ["#4C72B0", "#DD8452", "#55A868"]
bar_width = 0.25

x_positions = np.arange(len(instances))
fig, ax = plt.subplots(figsize=(max(12, len(instances) * 0.7), 5))

for k, (aspect, color) in enumerate(zip(ASPECTS, colors_aspects)):
    values = [instance_aspect_means[inst][aspect] for inst in instances]
    offset = (k - len(ASPECTS) / 2 + 0.5) * bar_width
    bars = ax.bar(
        x_positions + offset, values,
        width=bar_width, label=aspect.capitalize(),
        color=color, alpha=0.85
    )
    for bar, val in zip(bars, values):
        if not np.isnan(val):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height() + 0.05,
                f"{val:.1f}", ha="center", va="bottom", fontsize=7
            )

ax.set_xticks(x_positions)
ax.set_xticklabels([f"#{inst}" for inst in instances], fontsize=9, rotation=45, ha="right")
ax.set_ylim(0.5, 5.5)
ax.set_ylabel("Aggregate score (averaged across personas)", fontsize=10)
ax.set_xlabel("Instance", fontsize=10)
ax.set_title("Per-Instance Aggregate Scores", fontweight="bold")
ax.axhline(y=3, color="gray", linestyle="--", linewidth=0.8, alpha=0.6)
ax.legend(title="Aspect", fontsize=9, loc="lower left")
ax.grid(axis="y", linestyle="--", alpha=0.3)

fig.tight_layout()
fig.savefig("visualisations/evaluation/aggregate_per_instance.svg", dpi=150, bbox_inches="tight")
print("Saved aggregate_per_instance.svg")
plt.close(fig)
# Out:
# Saved aggregate_per_instance.svg
